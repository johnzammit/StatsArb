# %%
# !pip install python-binance
# !pip install python-dotenv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the api keys from your local .env file
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

binance_api_key = os.getenv('binanceAPIKey')
binance_secret_key = os.getenv('binanceSecretKey')

# %%
from binance.client import Client
client = Client(binance_api_key, 
                binance_secret_key,
                tld='us')

# %%
all_tickers_info = client.get_all_tickers()
all_tickers_info[:20]
# Out:
# [{'symbol': 'BTCUSD4', 'price': '22882.5400'},
#  {'symbol': 'ETHUSD4', 'price': '1626.0300'},
#  {'symbol': 'XRPUSD', 'price': '0.2970'},
#  {'symbol': 'BCHUSD4', 'price': '134.2000'},
#  {'symbol': 'LTCUSD4', 'price': '96.2100'},
#  {'symbol': 'USDTUSD4', 'price': '1.0003'},
#  {'symbol': 'BTCUSDT', 'price': '27926.00000000'},
#  {'symbol': 'ETHUSDT', 'price': '1632.15000000'},
#  {'symbol': 'XRPUSDT', 'price': '0.51770000'},
#  {'symbol': 'BCHUSDT', 'price': '227.40000000'},
#  {'symbol': 'LTCUSDT', 'price': '65.13000000'},
#  {'symbol': 'BNBUSD4', 'price': '325.6257'},
#  {'symbol': 'BNBUSDT', 'price': '211.20000000'},
#  {'symbol': 'ETHBTC', 'price': '0.05853000'},
#  {'symbol': 'XRPBTC', 'price': '0.00000864'},
#  {'symbol': 'BNBBTC', 'price': '0.00760000'},
#  {'symbol': 'LTCBTC', 'price': '0.00234100'},
#  {'symbol': 'BCHBTC', 'price': '0.00422000'},
#  {'symbol': 'ADAUSD4', 'price': '0.3920'},
#  {'symbol': 'BATUSD4', 'price': '0.2843'}]

# %%
len(all_tickers_info)
# Out:
# 537

# %%
# Not entirely sure if we should use all of these... maybe we should ignore stable coins?
tickers = [ticker["symbol"] for ticker in all_tickers_info]
tickers[:20]
# Out:
# ['BTCUSD4',
#  'ETHUSD4',
#  'XRPUSD',
#  'BCHUSD4',
#  'LTCUSD4',
#  'USDTUSD4',
#  'BTCUSDT',
#  'ETHUSDT',
#  'XRPUSDT',
#  'BCHUSDT',
#  'LTCUSDT',
#  'BNBUSD4',
#  'BNBUSDT',
#  'ETHBTC',
#  'XRPBTC',
#  'BNBBTC',
#  'LTCBTC',
#  'BCHBTC',
#  'ADAUSD4',
#  'BATUSD4']

# %%
only_usd_coins = [coin for coin in tickers if 'USD' in coin]
only_usd_coins[:20]
# Out:
# ['BTCUSD4',
#  'ETHUSD4',
#  'XRPUSD',
#  'BCHUSD4',
#  'LTCUSD4',
#  'USDTUSD4',
#  'BTCUSDT',
#  'ETHUSDT',
#  'XRPUSDT',
#  'BCHUSDT',
#  'LTCUSDT',
#  'BNBUSD4',
#  'BNBUSDT',
#  'ADAUSD4',
#  'BATUSD4',
#  'ETCUSD4',
#  'XLMUSD4',
#  'ZRXUSD4',
#  'ADAUSDT',
#  'BATUSDT']

# %%
# Looks like this is still too many, I definitely need to read more about crypto to know which ones are actually unique
len(only_usd_coins)
# Out:
# 510

# %%
# Maybe 2 years or less is reasonable for crypto, since it's still a new thing and is very volatile

# Eventually want to do this for many coins, right now this just gets data for the first symbol
# We should also think about what time granularity we want to use, and also what the time range should be
# We can try 10/15/30/60 minute intervals, and we can do at least 1000 data points

# We could also think about whether we want to download this data locally or not... 
# depends on how long it takes to get all of it, and how much space it takes up

data = None
for i in range(1):
    symbol = tickers[i]
    print(symbol)
    klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1DAY, "1 Oct, 2021") # Can change the time interval and start date
    data = pd.DataFrame(klines, columns = ['timestamp', 'open', 'high', 'low', 'close', 
                                           'volume', 'close_time', 'quote_av', 'trades', 
                                           'tb_base_av', 'tb_quote_av', 'ignore' ])
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    print("------------------------------------------------------")
# Out:
# BTCUSD4
# ------------------------------------------------------

# %%
data
# Out:
#                      timestamp        open        high         low  \
# 0   1970-01-01 00:27:13.046400  43825.0000  48483.6900  43282.5600
# 1   1970-01-01 00:27:13.132800  48163.5400  48356.5400  47444.1800
# 2   1970-01-01 00:27:13.219200  47656.2100  49242.6600  47107.0300
# 3   1970-01-01 00:27:13.305600  48228.1000  49500.0000  46920.8500
# 4   1970-01-01 00:27:13.392000  49224.8900  51917.0000  49054.5200
# ..                         ...         ...         ...         ...
# 489 1970-01-01 00:27:55.296000  23740.9500  24250.0000  23421.5000
# 490 1970-01-01 00:27:55.382400  23491.5000  23725.0000  23217.2800
# 491 1970-01-01 00:27:55.468800  23436.0200  23588.1700  23254.0000
# 492 1970-01-01 00:27:55.555200  23340.0500  23436.9300  22759.7800
# 493 1970-01-01 00:27:55.641600  22953.7400  23101.7500  22857.4000
#
#           close         volume     close_time        quote_av  trades  \
# 0    48151.0500  1729.09497600  1633132799999   80495261.8729  109872
# 1    47668.1200   627.86080500  1633219199999   30062317.2466   61404
# 2    48215.1400   707.23854800  1633305599999   34074843.2001   69284
# 3    49215.4900  1082.33020700  1633391999999   52332162.5510   98813
# 4    51466.0100  1145.60561400  1633478399999   57663919.4844   99126
# ..          ...            ...            ...             ...     ...
# 489  23484.1400  9171.10052500  1675382399999  218702054.6102  189660
# 490  23432.8500  5014.83685900  1675468799999  117772754.8256  116257
# 491  23340.0700  2931.52005300  1675555199999   68610911.3551   78200
# 492  22956.4100  4184.87707600  1675641599999   96776692.5208  104813
# 493  22882.5400   937.70397500  1675659599999   21554448.5727   19151
#
#         tb_base_av     tb_quote_av ignore
# 0     903.57067100   42082044.9606      0
# 1     309.79080700   14837270.8492      0
# 2     369.16542200   17791952.2962      0
# 3     521.67375700   25236518.3691      0
# 4     624.52254200   31446741.5878      0
# ..             ...             ...    ...
# 489  4497.37116300  107258771.7475      0
# 490  2477.30090600   58184215.4442      0
# 491  1401.50494500   32806264.5050      0
# 492  2054.01835000   47503106.4745      0
# 493   461.31952200   10604393.0511      0
#
# [494 rows x 12 columns]

# %%
data.dtypes
# Out:
# timestamp      datetime64[ns]
# open                   object
# high                   object
# low                    object
# close                  object
# volume                 object
# close_time              int64
# quote_av               object
# trades                  int64
# tb_base_av             object
# tb_quote_av            object
# ignore                 object
# dtype: object

# %%
# Idk why there are some columns of the object type, but let's try converting them to float I guess
columns_to_convert = ['open', 'high', 'low', 'close', 'volume', 'quote_av', 'tb_base_av', 'tb_quote_av', 'ignore']
# Convert selected columns to float
data[columns_to_convert] = data[columns_to_convert].astype(float)
data
# Out:
#                      timestamp      open      high       low     close  \
# 0   1970-01-01 00:27:13.046400  43825.00  48483.69  43282.56  48151.05
# 1   1970-01-01 00:27:13.132800  48163.54  48356.54  47444.18  47668.12
# 2   1970-01-01 00:27:13.219200  47656.21  49242.66  47107.03  48215.14
# 3   1970-01-01 00:27:13.305600  48228.10  49500.00  46920.85  49215.49
# 4   1970-01-01 00:27:13.392000  49224.89  51917.00  49054.52  51466.01
# ..                         ...       ...       ...       ...       ...
# 489 1970-01-01 00:27:55.296000  23740.95  24250.00  23421.50  23484.14
# 490 1970-01-01 00:27:55.382400  23491.50  23725.00  23217.28  23432.85
# 491 1970-01-01 00:27:55.468800  23436.02  23588.17  23254.00  23340.07
# 492 1970-01-01 00:27:55.555200  23340.05  23436.93  22759.78  22956.41
# 493 1970-01-01 00:27:55.641600  22953.74  23101.75  22857.40  22882.54
#
#           volume     close_time      quote_av  trades   tb_base_av  \
# 0    1729.094976  1633132799999  8.049526e+07  109872   903.570671
# 1     627.860805  1633219199999  3.006232e+07   61404   309.790807
# 2     707.238548  1633305599999  3.407484e+07   69284   369.165422
# 3    1082.330207  1633391999999  5.233216e+07   98813   521.673757
# 4    1145.605614  1633478399999  5.766392e+07   99126   624.522542
# ..           ...            ...           ...     ...          ...
# 489  9171.100525  1675382399999  2.187021e+08  189660  4497.371163
# 490  5014.836859  1675468799999  1.177728e+08  116257  2477.300906
# 491  2931.520053  1675555199999  6.861091e+07   78200  1401.504945
# 492  4184.877076  1675641599999  9.677669e+07  104813  2054.018350
# 493   937.703975  1675659599999  2.155445e+07   19151   461.319522
#
#       tb_quote_av  ignore
# 0    4.208204e+07     0.0
# 1    1.483727e+07     0.0
# 2    1.779195e+07     0.0
# 3    2.523652e+07     0.0
# 4    3.144674e+07     0.0
# ..            ...     ...
# 489  1.072588e+08     0.0
# 490  5.818422e+07     0.0
# 491  3.280626e+07     0.0
# 492  4.750311e+07     0.0
# 493  1.060439e+07     0.0
#
# [494 rows x 12 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['timestamp'], data['close'], label='Bitcoin Price')
plt.title('Bitcoin Price Time Series (BTCUSD4)')
plt.xlabel('Timestamp')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Now I will actually run that for loop on all of them, converting the columns as we get the data
coin_data_dict = {}
for i in range(len(tickers)):
    symbol = tickers[i]
    print(symbol)
    klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1DAY, "1 Oct, 2021") # Can change the time interval and start date
    curr_data = pd.DataFrame(klines, columns = ['timestamp', 'open', 'high', 'low', 'close', 
                                           'volume', 'close_time', 'quote_av', 'trades', 
                                           'tb_base_av', 'tb_quote_av', 'ignore' ])
    curr_data = curr_data[['timestamp', 'close']]
    curr_data['timestamp'] = pd.to_datetime(curr_data['timestamp'])
    curr_data['close'] = curr_data['close'].astype(float)
    coin_data_dict[symbol] = curr_data
    print("------------------------------------------------------ " + str(i))
# Out:
# BTCUSD4
# ------------------------------------------------------ 0
# ETHUSD4
# ------------------------------------------------------ 1
# XRPUSD
# ------------------------------------------------------ 2
# BCHUSD4
# ------------------------------------------------------ 3
# LTCUSD4
# ------------------------------------------------------ 4
# USDTUSD4
# ------------------------------------------------------ 5
# BTCUSDT
# ------------------------------------------------------ 6
# ETHUSDT
# ------------------------------------------------------ 7
# XRPUSDT
# ------------------------------------------------------ 8
# BCHUSDT
# ------------------------------------------------------ 9
# LTCUSDT
# ------------------------------------------------------ 10
# BNBUSD4
# ------------------------------------------------------ 11
# BNBUSDT
# ------------------------------------------------------ 12
# ETHBTC
# ------------------------------------------------------ 13
# XRPBTC
# ------------------------------------------------------ 14
# BNBBTC
# ------------------------------------------------------ 15
# LTCBTC
# ------------------------------------------------------ 16
# BCHBTC
# ------------------------------------------------------ 17
# ADAUSD4
# ------------------------------------------------------ 18
# BATUSD4
# ------------------------------------------------------ 19
# ETCUSD4
# ------------------------------------------------------ 20
# XLMUSD4
# ------------------------------------------------------ 21
# ZRXUSD4
# ------------------------------------------------------ 22
# ADAUSDT
# ------------------------------------------------------ 23
# BATUSDT
# ------------------------------------------------------ 24
# ETCUSDT
# ------------------------------------------------------ 25
# XLMUSDT
# ------------------------------------------------------ 26
# ZRXUSDT
# ------------------------------------------------------ 27
# LINKUSD4
# ------------------------------------------------------ 28
# RVNUSD4
# ------------------------------------------------------ 29
# DASHUSD4
# ------------------------------------------------------ 30
# ZECUSD4
# ------------------------------------------------------ 31
# ALGOUSD4
# ------------------------------------------------------ 32
# IOTAUSD4
# ------------------------------------------------------ 33
# BUSDUSD4
# ------------------------------------------------------ 34
# BTCBUSD
# ------------------------------------------------------ 35
# DOGEUSDT
# ------------------------------------------------------ 36
# WAVESUSD4
# ------------------------------------------------------ 37
# ATOMUSDT
# ------------------------------------------------------ 38
# ATOMUSD4
# ------------------------------------------------------ 39
# NEOUSDT
# ------------------------------------------------------ 40
# NEOUSD4
# ------------------------------------------------------ 41
# VETUSDT
# ------------------------------------------------------ 42
# QTUMUSDT
# ------------------------------------------------------ 43
# QTUMUSD4
# ------------------------------------------------------ 44
# NANOUSD
# ------------------------------------------------------ 45
# ICXUSD4
# ------------------------------------------------------ 46
# ENJUSD4
# ------------------------------------------------------ 47
# ONTUSD4
# ------------------------------------------------------ 48
# ONTUSDT
# ------------------------------------------------------ 49
# ZILUSD4
# ------------------------------------------------------ 50
# ZILBUSD
# ------------------------------------------------------ 51
# VETUSD4
# ------------------------------------------------------ 52
# BNBBUSD
# ------------------------------------------------------ 53
# XRPBUSD
# ------------------------------------------------------ 54
# ETHBUSD
# ------------------------------------------------------ 55
# ALGOBUSD
# ------------------------------------------------------ 56
# XTZUSD4
# ------------------------------------------------------ 57
# XTZBUSD
# ------------------------------------------------------ 58
# HBARUSD4
# ------------------------------------------------------ 59
# HBARBUSD
# ------------------------------------------------------ 60
# OMGUSD4
# ------------------------------------------------------ 61
# OMGBUSD
# ------------------------------------------------------ 62
# MATICUSD4
# ------------------------------------------------------ 63
# MATICBUSD
# ------------------------------------------------------ 64
# XTZBTC
# ------------------------------------------------------ 65
# ADABTC
# ------------------------------------------------------ 66
# REPBUSD
# ------------------------------------------------------ 67
# REPUSD
# ------------------------------------------------------ 68
# EOSBUSD
# ------------------------------------------------------ 69
# EOSUSD4
# ------------------------------------------------------ 70
# DOGEUSD4
# ------------------------------------------------------ 71
# KNCUSD4
# ------------------------------------------------------ 72
# KNCUSDT
# ------------------------------------------------------ 73
# VTHOUSDT
# ------------------------------------------------------ 74
# VTHOUSD4
# ------------------------------------------------------ 75
# USDCUSD4
# ------------------------------------------------------ 76
# COMPUSDT
# ------------------------------------------------------ 77
# COMPUSD4
# ------------------------------------------------------ 78
# MANAUSD4
# ------------------------------------------------------ 79
# HNTUSD4
# ------------------------------------------------------ 80
# HNTUSDT
# ------------------------------------------------------ 81
# MKRUSD4
# ------------------------------------------------------ 82
# MKRUSDT
# ------------------------------------------------------ 83
# DAIUSD4
# ------------------------------------------------------ 84
# ONEUSDT
# ------------------------------------------------------ 85
# ONEUSD4
# ------------------------------------------------------ 86
# BANDUSDT
# ------------------------------------------------------ 87
# BANDUSD4
# ------------------------------------------------------ 88
# STORJUSDT
# ------------------------------------------------------ 89
# STORJUSD4
# ------------------------------------------------------ 90
# BUSDUSDT
# ------------------------------------------------------ 91
# UNIUSD4
# ------------------------------------------------------ 92
# UNIUSDT
# ------------------------------------------------------ 93
# SOLUSD4
# ------------------------------------------------------ 94
# SOLUSDT
# ------------------------------------------------------ 95
# LINKBTC
# ------------------------------------------------------ 96
# VETBTC
# ------------------------------------------------------ 97
# UNIBTC
# ------------------------------------------------------ 98
# EGLDUSDT
# ------------------------------------------------------ 99
# EGLDUSD4
# ------------------------------------------------------ 100
# PAXGUSDT
# ------------------------------------------------------ 101
# PAXGUSD4
# ------------------------------------------------------ 102
# OXTUSDT
# ------------------------------------------------------ 103
# OXTUSD4
# ------------------------------------------------------ 104
# ZENUSDT
# ------------------------------------------------------ 105
# ZENUSD4
# ------------------------------------------------------ 106
# BTCUSDC
# ------------------------------------------------------ 107
# ONEBUSD
# ------------------------------------------------------ 108
# FILUSDT
# ------------------------------------------------------ 109
# FILUSD4
# ------------------------------------------------------ 110
# AAVEUSDT
# ------------------------------------------------------ 111
# AAVEUSD4
# ------------------------------------------------------ 112
# GRTUSDT
# ------------------------------------------------------ 113
# GRTUSD4
# ------------------------------------------------------ 114
# SUSHIUSD4
# ------------------------------------------------------ 115
# ANKRUSD4
# ------------------------------------------------------ 116
# AMPUSD
# ------------------------------------------------------ 117
# SHIBUSDT
# ------------------------------------------------------ 118
# SHIBBUSD
# ------------------------------------------------------ 119
# CRVUSDT
# ------------------------------------------------------ 120
# CRVUSD4
# ------------------------------------------------------ 121
# AXSUSDT
# ------------------------------------------------------ 122
# AXSUSD4
# ------------------------------------------------------ 123
# SOLBTC
# ------------------------------------------------------ 124
# AVAXUSDT
# ------------------------------------------------------ 125
# AVAXUSD4
# ------------------------------------------------------ 126
# CTSIUSDT
# ------------------------------------------------------ 127
# CTSIUSD4
# ------------------------------------------------------ 128
# DOTUSDT
# ------------------------------------------------------ 129
# DOTUSD4
# ------------------------------------------------------ 130
# YFIUSDT
# ------------------------------------------------------ 131
# YFIUSD4
# ------------------------------------------------------ 132
# 1INCHUSDT
# ------------------------------------------------------ 133
# 1INCHUSD4
# ------------------------------------------------------ 134
# FTMUSDT
# ------------------------------------------------------ 135
# FTMUSD4
# ------------------------------------------------------ 136
# USDCUSDT
# ------------------------------------------------------ 137
# ETHUSDC
# ------------------------------------------------------ 138
# USDCBUSD
# ------------------------------------------------------ 139
# MATICUSDT
# ------------------------------------------------------ 140
# MANAUSDT
# ------------------------------------------------------ 141
# MANABUSD
# ------------------------------------------------------ 142
# ALGOUSDT
# ------------------------------------------------------ 143
# ADABUSD
# ------------------------------------------------------ 144
# SOLBUSD
# ------------------------------------------------------ 145
# LINKUSDT
# ------------------------------------------------------ 146
# EOSUSDT
# ------------------------------------------------------ 147
# ZECUSDT
# ------------------------------------------------------ 148
# ENJUSDT
# ------------------------------------------------------ 149
# NEARUSDT
# ------------------------------------------------------ 150
# NEARBUSD
# ------------------------------------------------------ 151
# NEARUSD4
# ------------------------------------------------------ 152
# OMGUSDT
# ------------------------------------------------------ 153
# SUSHIUSDT
# ------------------------------------------------------ 154
# LRCUSDT
# ------------------------------------------------------ 155
# LRCUSD4
# ------------------------------------------------------ 156
# LRCBTC
# ------------------------------------------------------ 157
# KSHIBUSD4
# ------------------------------------------------------ 158
# LPTUSDT
# ------------------------------------------------------ 159
# LPTBUSD
# ------------------------------------------------------ 160
# LPTUSD4
# ------------------------------------------------------ 161
# POLYUSDT
# ------------------------------------------------------ 162
# POLYBUSD
# ------------------------------------------------------ 163
# POLYUSD
# ------------------------------------------------------ 164
# POLYBTC
# ------------------------------------------------------ 165
# MATICBTC
# ------------------------------------------------------ 166
# DOTBTC
# ------------------------------------------------------ 167
# NMRUSDT
# ------------------------------------------------------ 168
# NMRUSD4
# ------------------------------------------------------ 169
# SLPUSDT
# ------------------------------------------------------ 170
# SLPUSD4
# ------------------------------------------------------ 171
# ANTUSDT
# ------------------------------------------------------ 172
# ANTUSD4
# ------------------------------------------------------ 173
# XNOUSD4
# ------------------------------------------------------ 174
# CHZUSDT
# ------------------------------------------------------ 175
# CHZUSD4
# ------------------------------------------------------ 176
# OGNUSDT
# ------------------------------------------------------ 177
# OGNUSD4
# ------------------------------------------------------ 178
# GALAUSDT
# ------------------------------------------------------ 179
# GALAUSD4
# ------------------------------------------------------ 180
# TLMUSDT
# ------------------------------------------------------ 181
# TLMUSD4
# ------------------------------------------------------ 182
# SNXUSDT
# ------------------------------------------------------ 183
# SNXUSD4
# ------------------------------------------------------ 184
# AUDIOUSDT
# ------------------------------------------------------ 185
# AUDIOUSD4
# ------------------------------------------------------ 186
# ENSUSDT
# ------------------------------------------------------ 187
# MANABTC
# ------------------------------------------------------ 188
# ATOMBTC
# ------------------------------------------------------ 189
# AVAXBTC
# ------------------------------------------------------ 190
# WBTCBTC
# ------------------------------------------------------ 191
# REQUSDT
# ------------------------------------------------------ 192
# REQUSD4
# ------------------------------------------------------ 193
# APEUSDT
# ------------------------------------------------------ 194
# APEUSD4
# ------------------------------------------------------ 195
# FLUXUSDT
# ------------------------------------------------------ 196
# FLUXUSD4
# ------------------------------------------------------ 197
# TRXBTC
# ------------------------------------------------------ 198
# TRXBUSD
# ------------------------------------------------------ 199
# TRXUSDT
# ------------------------------------------------------ 200
# TRXUSD4
# ------------------------------------------------------ 201
# COTIUSDT
# ------------------------------------------------------ 202
# COTIUSD4
# ------------------------------------------------------ 203
# VOXELUSDT
# ------------------------------------------------------ 204
# VOXELUSD4
# ------------------------------------------------------ 205
# RLCUSDT
# ------------------------------------------------------ 206
# RLCUSD4
# ------------------------------------------------------ 207
# USTUSDT
# ------------------------------------------------------ 208
# USTUSD
# ------------------------------------------------------ 209
# BICOUSDT
# ------------------------------------------------------ 210
# BICOUSD4
# ------------------------------------------------------ 211
# API3USDT
# ------------------------------------------------------ 212
# API3USD4
# ------------------------------------------------------ 213
# ENSUSD4
# ------------------------------------------------------ 214
# BTCUST
# ------------------------------------------------------ 215
# BNTUSDT
# ------------------------------------------------------ 216
# BNTUSD4
# ------------------------------------------------------ 217
# IMXUSDT
# ------------------------------------------------------ 218
# IMXUSD4
# ------------------------------------------------------ 219
# SPELLUSDT
# ------------------------------------------------------ 220
# SPELLUSD4
# ------------------------------------------------------ 221
# JASMYUSDT
# ------------------------------------------------------ 222
# JASMYUSD4
# ------------------------------------------------------ 223
# FLOWUSDT
# ------------------------------------------------------ 224
# FLOWUSD4
# ------------------------------------------------------ 225
# GTCUSDT
# ------------------------------------------------------ 226
# GTCUSD4
# ------------------------------------------------------ 227
# THETAUSDT
# ------------------------------------------------------ 228
# THETAUSD4
# ------------------------------------------------------ 229
# TFUELUSDT
# ------------------------------------------------------ 230
# TFUELUSD4
# ------------------------------------------------------ 231
# OCEANUSDT
# ------------------------------------------------------ 232
# OCEANUSD4
# ------------------------------------------------------ 233
# LAZIOUSDT
# ------------------------------------------------------ 234
# LAZIOUSD4
# ------------------------------------------------------ 235
# SANTOSUSDT
# ------------------------------------------------------ 236
# SANTOSUSD4
# ------------------------------------------------------ 237
# ALPINEUSDT
# ------------------------------------------------------ 238
# ALPINEUSD4
# ------------------------------------------------------ 239
# PORTOUSDT
# ------------------------------------------------------ 240
# PORTOUSD4
# ------------------------------------------------------ 241
# RENUSDT
# ------------------------------------------------------ 242
# RENUSD4
# ------------------------------------------------------ 243
# CELRUSDT
# ------------------------------------------------------ 244
# CELRUSD4
# ------------------------------------------------------ 245
# SKLUSDT
# ------------------------------------------------------ 246
# SKLUSD4
# ------------------------------------------------------ 247
# VITEUSDT
# ------------------------------------------------------ 248
# VITEUSD4
# ------------------------------------------------------ 249
# WAXPUSDT
# ------------------------------------------------------ 250
# WAXPUSD4
# ------------------------------------------------------ 251
# LTOUSDT
# ------------------------------------------------------ 252
# LTOUSD4
# ------------------------------------------------------ 253
# FETUSDT
# ------------------------------------------------------ 254
# FETUSD4
# ------------------------------------------------------ 255
# BONDUSDT
# ------------------------------------------------------ 256
# BONDUSD4
# ------------------------------------------------------ 257
# LOKAUSDT
# ------------------------------------------------------ 258
# LOKAUSD4
# ------------------------------------------------------ 259
# ICPUSDT
# ------------------------------------------------------ 260
# ICPUSD4
# ------------------------------------------------------ 261
# TUSDT
# ------------------------------------------------------ 262
# TUSD4
# ------------------------------------------------------ 263
# OPUSDT
# ------------------------------------------------------ 264
# OPUSD4
# ------------------------------------------------------ 265
# ROSEUSDT
# ------------------------------------------------------ 266
# ROSEUSD4
# ------------------------------------------------------ 267
# CELOUSDT
# ------------------------------------------------------ 268
# CELOUSD4
# ------------------------------------------------------ 269
# KDAUSDT
# ------------------------------------------------------ 270
# KDAUSD4
# ------------------------------------------------------ 271
# KSMUSDT
# ------------------------------------------------------ 272
# KSMUSD4
# ------------------------------------------------------ 273
# ACHUSDT
# ------------------------------------------------------ 274
# ACHUSD4
# ------------------------------------------------------ 275
# DARUSDT
# ------------------------------------------------------ 276
# DARUSD4
# ------------------------------------------------------ 277
# RNDRUSDT
# ------------------------------------------------------ 278
# RNDRUSD4
# ------------------------------------------------------ 279
# SYSUSDT
# ------------------------------------------------------ 280
# SYSUSD4
# ------------------------------------------------------ 281
# RADUSDT
# ------------------------------------------------------ 282
# RADUSD4
# ------------------------------------------------------ 283
# ILVUSDT
# ------------------------------------------------------ 284
# ILVUSD4
# ------------------------------------------------------ 285
# LDOUSDT
# ------------------------------------------------------ 286
# LDOUSD4
# ------------------------------------------------------ 287
# RAREUSDT
# ------------------------------------------------------ 288
# RAREUSD4
# ------------------------------------------------------ 289
# LSKUSDT
# ------------------------------------------------------ 290
# LSKUSD4
# ------------------------------------------------------ 291
# DGBUSDT
# ------------------------------------------------------ 292
# DGBUSD4
# ------------------------------------------------------ 293
# REEFUSDT
# ------------------------------------------------------ 294
# REEFUSD4
# ------------------------------------------------------ 295
# SRMUSDT
# ------------------------------------------------------ 296
# SRMUSD
# ------------------------------------------------------ 297
# ALICEUSDT
# ------------------------------------------------------ 298
# ALICEUSD4
# ------------------------------------------------------ 299
# FORTHUSDT
# ------------------------------------------------------ 300
# FORTHUSD4
# ------------------------------------------------------ 301
# ASTRUSDT
# ------------------------------------------------------ 302
# ASTRUSD4
# ------------------------------------------------------ 303
# BTRSTUSDT
# ------------------------------------------------------ 304
# BTRSTUSD4
# ------------------------------------------------------ 305
# GALUSDT
# ------------------------------------------------------ 306
# GALUSD4
# ------------------------------------------------------ 307
# SANDUSDT
# ------------------------------------------------------ 308
# SANDUSD4
# ------------------------------------------------------ 309
# BALUSDT
# ------------------------------------------------------ 310
# BALUSD4
# ------------------------------------------------------ 311
# POLYXUSD4
# ------------------------------------------------------ 312
# GLMUSDT
# ------------------------------------------------------ 313
# GLMUSD4
# ------------------------------------------------------ 314
# CLVUSDT
# ------------------------------------------------------ 315
# CLVUSD4
# ------------------------------------------------------ 316
# TUSDUSDT
# ------------------------------------------------------ 317
# TUSDUSD4
# ------------------------------------------------------ 318
# QNTUSDT
# ------------------------------------------------------ 319
# QNTUSD4
# ------------------------------------------------------ 320
# STGUSDT
# ------------------------------------------------------ 321
# STGUSD4
# ------------------------------------------------------ 322
# AXLUSDT
# ------------------------------------------------------ 323
# AXLUSD4
# ------------------------------------------------------ 324
# KAVAUSDT
# ------------------------------------------------------ 325
# KAVAUSD4
# ------------------------------------------------------ 326
# APTUSDT
# ------------------------------------------------------ 327
# APTUSD4
# ------------------------------------------------------ 328
# MASKUSDT
# ------------------------------------------------------ 329
# MASKUSD4
# ------------------------------------------------------ 330
# BOSONUSDT
# ------------------------------------------------------ 331
# BOSONUSD4
# ------------------------------------------------------ 332
# PONDUSDT
# ------------------------------------------------------ 333
# PONDUSD4
# ------------------------------------------------------ 334
# SOLUSDC
# ------------------------------------------------------ 335
# ADAUSDC
# ------------------------------------------------------ 336
# MXCUSDT
# ------------------------------------------------------ 337
# MXCUSD4
# ------------------------------------------------------ 338
# JAMUSDT
# ------------------------------------------------------ 339
# JAMUSD4
# ------------------------------------------------------ 340
# TRACUSDT
# ------------------------------------------------------ 341
# PROMUSDT
# ------------------------------------------------------ 342
# PROMUSD4
# ------------------------------------------------------ 343
# DIAUSDT
# ------------------------------------------------------ 344
# DIAUSD4
# ------------------------------------------------------ 345
# BTCDAI
# ------------------------------------------------------ 346
# ETHDAI
# ------------------------------------------------------ 347
# ADAETH
# ------------------------------------------------------ 348
# DOGEBTC
# ------------------------------------------------------ 349
# LOOMUSDT
# ------------------------------------------------------ 350
# LOOMUSD4
# ------------------------------------------------------ 351
# STMXUSDT
# ------------------------------------------------------ 352
# BTCUSD
# ------------------------------------------------------ 353
# ETHUSD
# ------------------------------------------------------ 354
# BCHUSD
# ------------------------------------------------------ 355
# LTCUSD
# ------------------------------------------------------ 356
# USDTUSD
# ------------------------------------------------------ 357
# BNBUSD
# ------------------------------------------------------ 358
# ADAUSD
# ------------------------------------------------------ 359
# BATUSD
# ------------------------------------------------------ 360
# ETCUSD
# ------------------------------------------------------ 361
# XLMUSD
# ------------------------------------------------------ 362
# ZRXUSD
# ------------------------------------------------------ 363
# LINKUSD
# ------------------------------------------------------ 364
# RVNUSD
# ------------------------------------------------------ 365
# DASHUSD
# ------------------------------------------------------ 366
# ZECUSD
# ------------------------------------------------------ 367
# ALGOUSD
# ------------------------------------------------------ 368
# IOTAUSD
# ------------------------------------------------------ 369
# BUSDUSD
# ------------------------------------------------------ 370
# WAVESUSD
# ------------------------------------------------------ 371
# ATOMUSD
# ------------------------------------------------------ 372
# NEOUSD
# ------------------------------------------------------ 373
# QTUMUSD
# ------------------------------------------------------ 374
# ICXUSD
# ------------------------------------------------------ 375
# ENJUSD
# ------------------------------------------------------ 376
# ONTUSD
# ------------------------------------------------------ 377
# ZILUSD
# ------------------------------------------------------ 378
# VETUSD
# ------------------------------------------------------ 379
# XTZUSD
# ------------------------------------------------------ 380
# HBARUSD
# ------------------------------------------------------ 381
# OMGUSD
# ------------------------------------------------------ 382
# MATICUSD
# ------------------------------------------------------ 383
# EOSUSD
# ------------------------------------------------------ 384
# DOGEUSD
# ------------------------------------------------------ 385
# KNCUSD
# ------------------------------------------------------ 386
# VTHOUSD
# ------------------------------------------------------ 387
# USDCUSD
# ------------------------------------------------------ 388
# COMPUSD
# ------------------------------------------------------ 389
# MANAUSD
# ------------------------------------------------------ 390
# HNTUSD
# ------------------------------------------------------ 391
# MKRUSD
# ------------------------------------------------------ 392
# DAIUSD
# ------------------------------------------------------ 393
# ONEUSD
# ------------------------------------------------------ 394
# BANDUSD
# ------------------------------------------------------ 395
# STORJUSD
# ------------------------------------------------------ 396
# UNIUSD
# ------------------------------------------------------ 397
# SOLUSD
# ------------------------------------------------------ 398
# EGLDUSD
# ------------------------------------------------------ 399
# PAXGUSD
# ------------------------------------------------------ 400
# OXTUSD
# ------------------------------------------------------ 401
# ZENUSD
# ------------------------------------------------------ 402
# FILUSD
# ------------------------------------------------------ 403
# AAVEUSD
# ------------------------------------------------------ 404
# GRTUSD
# ------------------------------------------------------ 405
# SUSHIUSD
# ------------------------------------------------------ 406
# ANKRUSD
# ------------------------------------------------------ 407
# CRVUSD
# ------------------------------------------------------ 408
# AXSUSD
# ------------------------------------------------------ 409
# AVAXUSD
# ------------------------------------------------------ 410
# CTSIUSD
# ------------------------------------------------------ 411
# DOTUSD
# ------------------------------------------------------ 412
# YFIUSD
# ------------------------------------------------------ 413
# 1INCHUSD
# ------------------------------------------------------ 414
# FTMUSD
# ------------------------------------------------------ 415
# NEARUSD
# ------------------------------------------------------ 416
# LRCUSD
# ------------------------------------------------------ 417
# KSHIBUSD
# ------------------------------------------------------ 418
# LPTUSD
# ------------------------------------------------------ 419
# NMRUSD
# ------------------------------------------------------ 420
# SLPUSD
# ------------------------------------------------------ 421
# ANTUSD
# ------------------------------------------------------ 422
# XNOUSD
# ------------------------------------------------------ 423
# CHZUSD
# ------------------------------------------------------ 424
# OGNUSD
# ------------------------------------------------------ 425
# GALAUSD
# ------------------------------------------------------ 426
# TLMUSD
# ------------------------------------------------------ 427
# SNXUSD
# ------------------------------------------------------ 428
# AUDIOUSD
# ------------------------------------------------------ 429
# REQUSD
# ------------------------------------------------------ 430
# APEUSD
# ------------------------------------------------------ 431
# FLUXUSD
# ------------------------------------------------------ 432
# TRXUSD
# ------------------------------------------------------ 433
# COTIUSD
# ------------------------------------------------------ 434
# VOXELUSD
# ------------------------------------------------------ 435
# RLCUSD
# ------------------------------------------------------ 436
# BICOUSD
# ------------------------------------------------------ 437
# API3USD
# ------------------------------------------------------ 438
# ENSUSD
# ------------------------------------------------------ 439
# BNTUSD
# ------------------------------------------------------ 440
# IMXUSD
# ------------------------------------------------------ 441
# SPELLUSD
# ------------------------------------------------------ 442
# JASMYUSD
# ------------------------------------------------------ 443
# FLOWUSD
# ------------------------------------------------------ 444
# GTCUSD
# ------------------------------------------------------ 445
# THETAUSD
# ------------------------------------------------------ 446
# TFUELUSD
# ------------------------------------------------------ 447
# OCEANUSD
# ------------------------------------------------------ 448
# LAZIOUSD
# ------------------------------------------------------ 449
# SANTOSUSD
# ------------------------------------------------------ 450
# ALPINEUSD
# ------------------------------------------------------ 451
# PORTOUSD
# ------------------------------------------------------ 452
# RENUSD
# ------------------------------------------------------ 453
# CELRUSD
# ------------------------------------------------------ 454
# SKLUSD
# ------------------------------------------------------ 455
# VITEUSD
# ------------------------------------------------------ 456
# WAXPUSD
# ------------------------------------------------------ 457
# LTOUSD
# ------------------------------------------------------ 458
# FETUSD
# ------------------------------------------------------ 459
# BONDUSD
# ------------------------------------------------------ 460
# LOKAUSD
# ------------------------------------------------------ 461
# ICPUSD
# ------------------------------------------------------ 462
# TUSD
# ------------------------------------------------------ 463
# OPUSD
# ------------------------------------------------------ 464
# ROSEUSD
# ------------------------------------------------------ 465
# CELOUSD
# ------------------------------------------------------ 466
# KDAUSD
# ------------------------------------------------------ 467
# KSMUSD
# ------------------------------------------------------ 468
# ACHUSD
# ------------------------------------------------------ 469
# DARUSD
# ------------------------------------------------------ 470
# RNDRUSD
# ------------------------------------------------------ 471
# SYSUSD
# ------------------------------------------------------ 472
# RADUSD
# ------------------------------------------------------ 473
# ILVUSD
# ------------------------------------------------------ 474
# LDOUSD
# ------------------------------------------------------ 475
# RAREUSD
# ------------------------------------------------------ 476
# LSKUSD
# ------------------------------------------------------ 477
# DGBUSD
# ------------------------------------------------------ 478
# REEFUSD
# ------------------------------------------------------ 479
# ALICEUSD
# ------------------------------------------------------ 480
# FORTHUSD
# ------------------------------------------------------ 481
# ASTRUSD
# ------------------------------------------------------ 482
# BTRSTUSD
# ------------------------------------------------------ 483
# GALUSD
# ------------------------------------------------------ 484
# SANDUSD
# ------------------------------------------------------ 485
# BALUSD
# ------------------------------------------------------ 486
# POLYXUSD
# ------------------------------------------------------ 487
# GLMUSD
# ------------------------------------------------------ 488
# CLVUSD
# ------------------------------------------------------ 489
# TUSDUSD
# ------------------------------------------------------ 490
# QNTUSD
# ------------------------------------------------------ 491
# STGUSD
# ------------------------------------------------------ 492
# AXLUSD
# ------------------------------------------------------ 493
# KAVAUSD
# ------------------------------------------------------ 494
# APTUSD
# ------------------------------------------------------ 495
# MASKUSD
# ------------------------------------------------------ 496
# BOSONUSD
# ------------------------------------------------------ 497
# PONDUSD
# ------------------------------------------------------ 498
# MXCUSD
# ------------------------------------------------------ 499
# JAMUSD
# ------------------------------------------------------ 500
# PROMUSD
# ------------------------------------------------------ 501
# DIAUSD
# ------------------------------------------------------ 502
# LOOMUSD
# ------------------------------------------------------ 503
# STMXUSD
# ------------------------------------------------------ 504
# SHIBUSD
# ------------------------------------------------------ 505
# TRACUSD
# ------------------------------------------------------ 506
# POLYXUSDT
# ------------------------------------------------------ 507
# IOSTUSDT
# ------------------------------------------------------ 508
# IOSTUSD
# ------------------------------------------------------ 509
# MATICETH
# ------------------------------------------------------ 510
# SOLETH
# ------------------------------------------------------ 511
# FLOKI8USDT
# ------------------------------------------------------ 512
# FLOKI8USD
# ------------------------------------------------------ 513
# ARBUSDT
# ------------------------------------------------------ 514
# ARBUSD
# ------------------------------------------------------ 515
# FLOKIUSDT
# ------------------------------------------------------ 516
# FLOKIUSD
# ------------------------------------------------------ 517
# XECUSDT
# ------------------------------------------------------ 518
# XECUSD
# ------------------------------------------------------ 519
# BLURUSDT
# ------------------------------------------------------ 520
# BLURUSD
# ------------------------------------------------------ 521
# ANKRUSDT
# ------------------------------------------------------ 522
# DAIUSDT
# ------------------------------------------------------ 523
# DASHUSDT
# ------------------------------------------------------ 524
# HBARUSDT
# ------------------------------------------------------ 525
# ICXUSDT
# ------------------------------------------------------ 526
# IOTAUSDT
# ------------------------------------------------------ 527
# RVNUSDT
# ------------------------------------------------------ 528
# WAVESUSDT
# ------------------------------------------------------ 529
# XNOUSDT
# ------------------------------------------------------ 530
# XTZUSDT
# ------------------------------------------------------ 531
# ZILUSDT
# ------------------------------------------------------ 532
# ORBSUSDT
# ------------------------------------------------------ 533
# CUDOSUSDT
# ------------------------------------------------------ 534
# ADXUSDT
# ------------------------------------------------------ 535
# FORTUSDT
# ------------------------------------------------------ 536

# %%
# Turn dict into a list of pairs
coin_data_list = list(coin_data_dict.items())
coin_data_list[:3]
# Out:
# [('BTCUSD4',
#                        timestamp     close
#   0   1970-01-01 00:27:13.046400  48151.05
#   1   1970-01-01 00:27:13.132800  47668.12
#   2   1970-01-01 00:27:13.219200  48215.14
#   3   1970-01-01 00:27:13.305600  49215.49
#   4   1970-01-01 00:27:13.392000  51466.01
#   ..                         ...       ...
#   489 1970-01-01 00:27:55.296000  23484.14
#   490 1970-01-01 00:27:55.382400  23432.85
#   491 1970-01-01 00:27:55.468800  23340.07
#   492 1970-01-01 00:27:55.555200  22956.41
#   493 1970-01-01 00:27:55.641600  22882.54
#
#   [494 rows x 2 columns]),
#  ('ETHUSD4',
#                        timestamp    close
#   0   1970-01-01 00:27:13.046400  3310.71
#   1   1970-01-01 00:27:13.132800  3388.59
#   2   1970-01-01 00:27:13.219200  3420.60
#   3   1970-01-01 00:27:13.305600  3387.73
#   4   1970-01-01 00:27:13.392000  3516.50
#   ..                         ...      ...
#   489 1970-01-01 00:27:55.296000  1643.97
#   490 1970-01-01 00:27:55.382400  1664.16
#   491 1970-01-01 00:27:55.468800  1667.21
#   492 1970-01-01 00:27:55.555200  1630.84
#   493 1970-01-01 00:27:55.641600  1626.03
#
#   [494 rows x 2 columns]),
#  ('XRPUSD',
#   Empty DataFrame
#   Columns: [timestamp, close]
#   Index: [])]

# %%
coin_data_list[0][1]
# Out:
#                      timestamp     close
# 0   1970-01-01 00:27:13.046400  48151.05
# 1   1970-01-01 00:27:13.132800  47668.12
# 2   1970-01-01 00:27:13.219200  48215.14
# 3   1970-01-01 00:27:13.305600  49215.49
# 4   1970-01-01 00:27:13.392000  51466.01
# ..                         ...       ...
# 489 1970-01-01 00:27:55.296000  23484.14
# 490 1970-01-01 00:27:55.382400  23432.85
# 491 1970-01-01 00:27:55.468800  23340.07
# 492 1970-01-01 00:27:55.555200  22956.41
# 493 1970-01-01 00:27:55.641600  22882.54
#
# [494 rows x 2 columns]

# %%
from statsmodels.tsa.stattools import coint

# %%
# Assuming that we have gotten data on many different coins, we can go through all the pairs 
# and run the cointegration test on them

cointegrated_pairs = []
for i in range(len(coin_data_list)):
    for j in range(i + 1, len(coin_data_list)):
        first_coin_name = coin_data_list[i][0]
        first_coin_close = coin_data_list[i][1]['close']

        second_coin_name = coin_data_list[j][0]
        second_coin_close = coin_data_list[j][1]['close']

        # Might need to do some checking of the close data, because we might not have gotten all of it for all coins properly
        if len(first_coin_close) == 0 or len(second_coin_close) == 0 or len(first_coin_close) != len(second_coin_close):
            continue

        _, pvalue, _ = coint(first_coin_close, second_coin_close)

        if pvalue < 0.05:
            print(first_coin_name + " and " + second_coin_name + ": pval = " + str(pvalue))
            cointegrated_pairs.append((first_coin_name, second_coin_name))
# Out:
# BTCUSD4 and ADAUSD4: pval = 0.01861812189022572
# BTCUSD4 and ZRXUSD4: pval = 0.013915474821066313
# BTCUSD4 and ALGOUSD4: pval = 0.03404030173565346
# BTCUSD4 and ENJUSD4: pval = 0.026573693816120052
# BTCUSD4 and XTZUSD4: pval = 0.0009836461692861868
# BTCUSD4 and HNTUSD4: pval = 0.0001286886755951654
# BTCUSD4 and MKRUSD4: pval = 0.03058610989346438
# BTCUSD4 and SOLUSD4: pval = 0.046285083831076684
# BTCUSD4 and EGLDUSD4: pval = 0.01835611128104336
# BTCUSD4 and FILUSD4: pval = 0.041895208078167046
# BTCUSD4 and AAVEUSD4: pval = 0.009012022697995122
# BTCUSD4 and ANKRUSD4: pval = 0.004297361467843286
# ETHUSD4 and BCHUSD4: pval = 0.03958368657839353
# ETHUSD4 and ADAUSD4: pval = 0.031211764336673265
# ETHUSD4 and ZRXUSD4: pval = 0.018644816010833894
# ETHUSD4 and DASHUSD4: pval = 0.022840148244726147
# ETHUSD4 and ZECUSD4: pval = 0.04306773493602237
# ETHUSD4 and ATOMUSD4: pval = 0.03977744174658173
# ETHUSD4 and ICXUSD4: pval = 0.032038124350250566
# ETHUSD4 and ONTUSD4: pval = 0.03877662223973623
# ETHUSD4 and HBARUSD4: pval = 0.021666203979176613
# ETHUSD4 and HNTUSD4: pval = 0.01773551738890293
# ETHUSD4 and STORJUSD4: pval = 0.0228940900237547
# ETHUSD4 and EGLDUSD4: pval = 0.01819185636928332
# ETHUSD4 and OXTUSD4: pval = 0.0032542540098807623
# ETHUSD4 and ANKRUSD4: pval = 0.000767401737678607
# BCHUSD4 and BNBUSD4: pval = 0.03965751364598802
# BCHUSD4 and BATUSD4: pval = 0.0019188137177806556
# BCHUSD4 and ZRXUSD4: pval = 0.01382152697739047
# BCHUSD4 and LINKUSD4: pval = 0.04313288880864756
# BCHUSD4 and DASHUSD4: pval = 0.02413493131685611
# BCHUSD4 and ZECUSD4: pval = 0.023110657412385265
# BCHUSD4 and ENJUSD4: pval = 2.8329577988948887e-05
# BCHUSD4 and ONTUSD4: pval = 0.029991369945721682
# BCHUSD4 and VETUSD4: pval = 0.02714129777713555
# BCHUSD4 and MANAUSD4: pval = 0.00026390078896636703
# BCHUSD4 and HNTUSD4: pval = 0.0002878801429206215
# BCHUSD4 and MKRUSD4: pval = 0.038949304516131246
# BCHUSD4 and ONEUSD4: pval = 0.02744135107840162
# BCHUSD4 and BANDUSD4: pval = 0.0013133892514530403
# BCHUSD4 and STORJUSD4: pval = 0.032589331942804875
# BCHUSD4 and SOLUSD4: pval = 1.517308133018787e-05
# BCHUSD4 and EGLDUSD4: pval = 0.011476915269565971
# BCHUSD4 and FILUSD4: pval = 0.0017933831805979471
# BCHUSD4 and AAVEUSD4: pval = 0.019621216690340285
# BCHUSD4 and GRTUSD4: pval = 0.015828067241247388
# BCHUSD4 and ANKRUSD4: pval = 0.0036108174343586065
# BCHUSD4 and CRVUSD4: pval = 0.03172371697209347
# LTCUSD4 and BNBUSD4: pval = 0.03443264186689614
# LTCUSD4 and MANAUSD4: pval = 0.022582375529774414
# LTCUSD4 and BANDUSD4: pval = 0.001302758521193715
# LTCUSD4 and FILUSD4: pval = 0.001884326650393502
# USDTUSD4 and BNBUSD4: pval = 0.0027545841947247385
# USDTUSD4 and ADAUSD4: pval = 0.006123465385100466
# USDTUSD4 and BATUSD4: pval = 0.003656837688444949
# USDTUSD4 and ETCUSD4: pval = 0.0019312052542964958
# USDTUSD4 and XLMUSD4: pval = 0.006351022459640917
# USDTUSD4 and ZRXUSD4: pval = 0.007947840533841248
# USDTUSD4 and LINKUSD4: pval = 0.0038733156684994975
# USDTUSD4 and RVNUSD4: pval = 0.0026175863124319834
# USDTUSD4 and DASHUSD4: pval = 0.003969917777213942
# USDTUSD4 and ZECUSD4: pval = 0.0072998251265928025
# USDTUSD4 and ALGOUSD4: pval = 0.006000850138048814
# USDTUSD4 and IOTAUSD4: pval = 0.003550277402420697
# USDTUSD4 and BUSDUSD4: pval = 0.03000894062777063
# USDTUSD4 and WAVESUSD4: pval = 0.009130174446986663
# USDTUSD4 and ATOMUSD4: pval = 0.0016853420063204078
# USDTUSD4 and NEOUSD4: pval = 0.005040917272140635
# USDTUSD4 and QTUMUSD4: pval = 0.00475235314940324
# USDTUSD4 and ICXUSD4: pval = 0.006786568841736004
# USDTUSD4 and ENJUSD4: pval = 0.0028993656971731878
# USDTUSD4 and ONTUSD4: pval = 0.004665756003688637
# USDTUSD4 and ZILUSD4: pval = 0.016034217332123377
# USDTUSD4 and VETUSD4: pval = 0.0060033360711174155
# USDTUSD4 and XTZUSD4: pval = 0.00519662531294262
# USDTUSD4 and HBARUSD4: pval = 0.003562484870585878
# USDTUSD4 and OMGUSD4: pval = 0.008797240988908848
# USDTUSD4 and MATICUSD4: pval = 0.000964793043520641
# USDTUSD4 and EOSUSD4: pval = 0.0036998631425779823
# USDTUSD4 and DOGEUSD4: pval = 0.007030979648341389
# USDTUSD4 and VTHOUSD4: pval = 0.00655084835097183
# USDTUSD4 and USDCUSD4: pval = 0.014884129416404103
# USDTUSD4 and COMPUSD4: pval = 0.0058727253138221224
# USDTUSD4 and MANAUSD4: pval = 0.0025369121033011663
# USDTUSD4 and HNTUSD4: pval = 0.00409731276346697
# USDTUSD4 and MKRUSD4: pval = 0.005294682871238359
# USDTUSD4 and ONEUSD4: pval = 0.0037324095240254206
# USDTUSD4 and BANDUSD4: pval = 0.005002221900074075
# USDTUSD4 and STORJUSD4: pval = 0.005039935411321087
# USDTUSD4 and UNIUSD4: pval = 0.00402327079470761
# USDTUSD4 and SOLUSD4: pval = 0.0052829773121976925
# USDTUSD4 and EGLDUSD4: pval = 0.003733315801085211
# USDTUSD4 and PAXGUSD4: pval = 0.020969963266278917
# USDTUSD4 and OXTUSD4: pval = 0.003878600854731113
# USDTUSD4 and ZENUSD4: pval = 0.004293994785832628
# USDTUSD4 and FILUSD4: pval = 0.0056672025852001215
# USDTUSD4 and AAVEUSD4: pval = 0.005541972287239812
# USDTUSD4 and GRTUSD4: pval = 0.0050361720532294185
# USDTUSD4 and SUSHIUSD4: pval = 0.006117433542773927
# USDTUSD4 and ANKRUSD4: pval = 0.003369205129939748
# USDTUSD4 and CRVUSD4: pval = 0.0034707147988766195
# USDTUSD4 and VITEUSDT: pval = 0.01825130600895116
# BTCUSDT and BTCUSDC: pval = 2.1381881157513825e-06
# BTCUSDT and FILUSDT: pval = 0.0273991117143177
# BTCUSDT and SHIBUSDT: pval = 0.0038012118121206443
# ETHUSDT and ADAUSDT: pval = 0.02128295879347184
# ETHUSDT and ATOMUSDT: pval = 0.024033082489956354
# ETHUSDT and NEOUSDT: pval = 0.04266250719640248
# ETHUSDT and VTHOUSDT: pval = 0.016787548929229016
# ETHUSDT and ONEUSDT: pval = 0.04444867598725136
# ETHUSDT and OXTUSDT: pval = 0.025288219801239863
# ETHUSDT and FILUSDT: pval = 0.011736921913059785
# ETHUSDT and SHIBUSDT: pval = 0.024637588625454954
# BCHUSDT and BATUSDT: pval = 0.005296022654258495
# BCHUSDT and ETHBUSD: pval = 0.01111454407653946
# BCHUSDT and MKRUSDT: pval = 0.00759949265513096
# BCHUSDT and ONEUSDT: pval = 0.01920739136996652
# BCHUSDT and SHIBUSDT: pval = 0.0006910492481912446
# BCHUSDT and CRVUSDT: pval = 0.048755051016476175
# LTCUSDT and FILUSDT: pval = 0.002676833251664201
# LTCUSDT and SHIBUSDT: pval = 0.0038492900154215855
# BNBUSD4 and ADAUSD4: pval = 0.033092102629758986
# BNBUSD4 and XLMUSD4: pval = 0.02008377916312297
# BNBUSD4 and LINKUSD4: pval = 0.036226067733952906
# BNBUSD4 and RVNUSD4: pval = 0.026347096160941767
# BNBUSD4 and DASHUSD4: pval = 0.018419546239855193
# BNBUSD4 and ALGOUSD4: pval = 0.015066940967232725
# BNBUSD4 and IOTAUSD4: pval = 0.0171919099570881
# BNBUSD4 and QTUMUSD4: pval = 0.026876220562354676
# BNBUSD4 and ENJUSD4: pval = 0.005515813861389796
# BNBUSD4 and ONTUSD4: pval = 0.04092529723921594
# BNBUSD4 and HBARUSD4: pval = 0.03681480101803206
# BNBUSD4 and VTHOUSD4: pval = 0.04485413754445273
# BNBUSD4 and COMPUSD4: pval = 0.018538393124281734
# BNBUSD4 and ONEUSD4: pval = 0.014147608804641686
# BNBUSD4 and BANDUSD4: pval = 0.030271363957748744
# BNBUSD4 and STORJUSD4: pval = 0.01825106248697985
# BNBUSD4 and SOLUSD4: pval = 0.005503009689820897
# BNBUSD4 and EGLDUSD4: pval = 0.032914770227384246
# BNBUSD4 and OXTUSD4: pval = 0.026919027875725504
# BNBUSD4 and ZENUSD4: pval = 0.0036105013845200216
# BNBUSD4 and FILUSD4: pval = 0.018860087290154447
# BNBUSD4 and AAVEUSD4: pval = 0.049948088287387164
# BNBUSD4 and GRTUSD4: pval = 0.021023777331223743
# BNBUSD4 and ANKRUSD4: pval = 0.00037376732820119224
# BNBUSDT and ADAUSDT: pval = 0.0076467492338808465
# BNBUSDT and ZRXUSDT: pval = 0.031623001021501944
# BNBUSDT and ATOMUSDT: pval = 0.02606862702474359
# BNBUSDT and NEOUSDT: pval = 0.03275392029695074
# BNBUSDT and QTUMUSDT: pval = 0.017644564381980504
# BNBUSDT and ONTUSDT: pval = 0.001520623273742082
# BNBUSDT and BNBBUSD: pval = 0.029929782756168546
# BNBUSDT and VTHOUSDT: pval = 0.028157531589202714
# BNBUSDT and COMPUSDT: pval = 0.02340893522380181
# BNBUSDT and ONEUSDT: pval = 0.006861289477359239
# BNBUSDT and BANDUSDT: pval = 0.01069677594010685
# BNBUSDT and UNIUSDT: pval = 0.03062919549946051
# BNBUSDT and SOLUSDT: pval = 0.02777385197943671
# BNBUSDT and ZENUSDT: pval = 0.029877444882297717
# BNBUSDT and FILUSDT: pval = 0.006501408864119605
# BNBUSDT and AAVEUSDT: pval = 0.015617857982515203
# BNBUSDT and SHIBUSDT: pval = 0.0131836602073661
# BCHBTC and ONEBUSD: pval = 0.0020475850279794688
# ADAUSD4 and BATUSD4: pval = 0.00790395359288105
# ADAUSD4 and XLMUSD4: pval = 9.474562658463597e-09
# ADAUSD4 and ZRXUSD4: pval = 0.01360890294800351
# ADAUSD4 and LINKUSD4: pval = 6.10180987717059e-05
# ADAUSD4 and RVNUSD4: pval = 0.011553381056694925
# ADAUSD4 and DASHUSD4: pval = 0.0269066506909251
# ADAUSD4 and ZECUSD4: pval = 0.005814031193759048
# ADAUSD4 and ALGOUSD4: pval = 0.031395012702800984
# ADAUSD4 and IOTAUSD4: pval = 0.02043796981207515
# ADAUSD4 and NEOUSD4: pval = 0.0066472037962476685
# ADAUSD4 and QTUMUSD4: pval = 0.00011260106976291765
# ADAUSD4 and ICXUSD4: pval = 0.013559842455906941
# ADAUSD4 and ENJUSD4: pval = 2.7137841302613103e-05
# ADAUSD4 and ONTUSD4: pval = 0.01992015379058679
# ADAUSD4 and VETUSD4: pval = 0.0008046818563514704
# ADAUSD4 and XTZUSD4: pval = 0.001718408577937939
# ADAUSD4 and HBARUSD4: pval = 0.0008319484529103661
# ADAUSD4 and MATICUSD4: pval = 0.033041310322968476
# ADAUSD4 and EOSUSD4: pval = 1.9604021947952435e-05
# ADAUSD4 and VTHOUSD4: pval = 0.02145537172374374
# ADAUSD4 and COMPUSD4: pval = 0.010652361624191824
# ADAUSD4 and MANAUSD4: pval = 0.0002840253352083341
# ADAUSD4 and HNTUSD4: pval = 0.0014231472946462788
# ADAUSD4 and MKRUSD4: pval = 0.013350072680265177
# ADAUSD4 and ONEUSD4: pval = 0.0013762868115536789
# ADAUSD4 and BANDUSD4: pval = 0.0037576609653798532
# ADAUSD4 and STORJUSD4: pval = 0.008119000434977713
# ADAUSD4 and SOLUSD4: pval = 2.552565233823729e-06
# ADAUSD4 and EGLDUSD4: pval = 0.0039003943338195204
# ADAUSD4 and ZENUSD4: pval = 0.0018356417120969732
# ADAUSD4 and AAVEUSD4: pval = 0.0003199735786336861
# ADAUSD4 and GRTUSD4: pval = 2.8047666646034786e-05
# ADAUSD4 and ANKRUSD4: pval = 0.001082680924813477
# ADAUSD4 and CRVUSD4: pval = 0.0006005435609516346
# BATUSD4 and XLMUSD4: pval = 0.02812995337535075
# BATUSD4 and IOTAUSD4: pval = 0.012474289402691201
# BATUSD4 and HBARUSD4: pval = 0.03576968940680695
# BATUSD4 and MANAUSD4: pval = 0.024133364868440317
# BATUSD4 and HNTUSD4: pval = 0.0012874003334724506
# BATUSD4 and ONEUSD4: pval = 0.008340379492354675
# BATUSD4 and STORJUSD4: pval = 0.0358366734813276
# BATUSD4 and CRVUSD4: pval = 0.007692045898658249
# XLMUSD4 and ZRXUSD4: pval = 0.03026111780858778
# XLMUSD4 and LINKUSD4: pval = 0.017878423436034317
# XLMUSD4 and ICXUSD4: pval = 0.00520151919624426
# XLMUSD4 and ENJUSD4: pval = 3.159745411799458e-06
# XLMUSD4 and ONTUSD4: pval = 0.016283601424752867
# XLMUSD4 and VETUSD4: pval = 0.001288646765026226
# XLMUSD4 and EOSUSD4: pval = 0.0015255984759109293
# XLMUSD4 and VTHOUSD4: pval = 0.006011922380984953
# XLMUSD4 and MANAUSD4: pval = 0.002326832164607114
# XLMUSD4 and HNTUSD4: pval = 2.0226496420792303e-05
# XLMUSD4 and ONEUSD4: pval = 0.0253584405639697
# XLMUSD4 and STORJUSD4: pval = 0.019606448941642186
# XLMUSD4 and SOLUSD4: pval = 5.721720014428884e-10
# XLMUSD4 and EGLDUSD4: pval = 0.0001166182781248553
# XLMUSD4 and OXTUSD4: pval = 0.019646052307064097
# XLMUSD4 and ZENUSD4: pval = 0.019303475456376264
# XLMUSD4 and FILUSD4: pval = 0.03351676112935106
# XLMUSD4 and AAVEUSD4: pval = 0.014091435387466943
# XLMUSD4 and GRTUSD4: pval = 7.237190345866036e-05
# XLMUSD4 and ANKRUSD4: pval = 0.007785747799377212
# XLMUSD4 and CRVUSD4: pval = 0.001226087880014356
# ZRXUSD4 and ZECUSD4: pval = 0.022159127805198405
# ZRXUSD4 and ICXUSD4: pval = 0.015886084965118258
# ZRXUSD4 and ENJUSD4: pval = 0.03736480102037584
# ZRXUSD4 and MANAUSD4: pval = 0.018065196553999747
# ZRXUSD4 and HNTUSD4: pval = 0.019859213719181635
# ZRXUSD4 and SOLUSD4: pval = 0.03947423696250872
# ZRXUSD4 and EGLDUSD4: pval = 0.00910334726046327
# ZRXUSD4 and ZENUSD4: pval = 0.007531166604105488
# ZRXUSD4 and ANKRUSD4: pval = 0.03795587577353823
# ADAUSDT and BATUSDT: pval = 1.0756620375405993e-06
# ADAUSDT and XLMUSDT: pval = 0.0004683987926943427
# ADAUSDT and ZRXUSDT: pval = 0.0006584598004894289
# ADAUSDT and DOGEUSDT: pval = 0.009854619500106725
# ADAUSDT and ATOMUSDT: pval = 0.019477327699900574
# ADAUSDT and NEOUSDT: pval = 0.011889798036293742
# ADAUSDT and VETUSDT: pval = 1.6384634387423461e-07
# ADAUSDT and QTUMUSDT: pval = 0.00039205656799311614
# ADAUSDT and ONTUSDT: pval = 0.0015663060793457094
# ADAUSDT and BNBBUSD: pval = 0.0002654113404450968
# ADAUSDT and ETHBUSD: pval = 0.0015429686159875683
# ADAUSDT and KNCUSDT: pval = 0.015144706852588086
# ADAUSDT and VTHOUSDT: pval = 0.02607395139056429
# ADAUSDT and COMPUSDT: pval = 0.042333452270884635
# ADAUSDT and ONEUSDT: pval = 7.058513666366343e-05
# ADAUSDT and BANDUSDT: pval = 0.0001277327716545455
# ADAUSDT and STORJUSDT: pval = 0.00040561216009829136
# ADAUSDT and SOLUSDT: pval = 1.0791733672235585e-08
# ADAUSDT and EGLDUSDT: pval = 4.868306496269853e-06
# ADAUSDT and PAXGUSDT: pval = 0.031275413509625594
# ADAUSDT and OXTUSDT: pval = 0.0003447955221461956
# ADAUSDT and ZENUSDT: pval = 3.3686633242590474e-05
# ADAUSDT and AAVEUSDT: pval = 3.925432330893051e-06
# ADAUSDT and SHIBUSDT: pval = 7.182586561631834e-17
# ADAUSDT and CRVUSDT: pval = 3.533355542292883e-06
# ADAUSDT and USDTUSD: pval = 0.04217446052620101
# BATUSDT and XLMUSDT: pval = 0.0076423822234226
# BATUSDT and ZRXUSDT: pval = 0.025528817388310178
# BATUSDT and ATOMUSDT: pval = 0.0035021208681355063
# BATUSDT and NEOUSDT: pval = 0.01902418181121659
# BATUSDT and QTUMUSDT: pval = 0.02444739207486188
# BATUSDT and ONTUSDT: pval = 0.0010796653142938928
# BATUSDT and VTHOUSDT: pval = 0.01243761166326377
# BATUSDT and COMPUSDT: pval = 0.026955849385910686
# BATUSDT and ONEUSDT: pval = 0.0007079051523409329
# BATUSDT and BANDUSDT: pval = 0.033946317668339214
# BATUSDT and STORJUSDT: pval = 0.01870320664583305
# BATUSDT and UNIUSDT: pval = 0.014177806814322125
# BATUSDT and SOLUSDT: pval = 0.030678761024977665
# BATUSDT and OXTUSDT: pval = 0.022430157161314895
# BATUSDT and ZENUSDT: pval = 0.012355732677932637
# BATUSDT and FILUSDT: pval = 0.04678457895493733
# BATUSDT and AAVEUSDT: pval = 0.0022587223936196836
# BATUSDT and SHIBUSDT: pval = 0.01210150174880988
# BATUSDT and CRVUSDT: pval = 0.0006495081765043908
# ETCUSDT and BNBBUSD: pval = 0.043227311919280365
# ETCUSDT and ADABTC: pval = 0.038779143069789496
# ETCUSDT and STORJUSDT: pval = 0.01577395960473611
# ETCUSDT and SOLUSDT: pval = 0.049818004327553886
# ETCUSDT and LINKBTC: pval = 0.03300356634853652
# ETCUSDT and EGLDUSDT: pval = 0.035916969208688636
# ETCUSDT and ZENUSDT: pval = 0.030722111789369396
# ETCUSDT and SHIBUSDT: pval = 0.003132059176934848
# ETCUSDT and CRVUSDT: pval = 0.023282960177529323
# XLMUSDT and NEOUSDT: pval = 0.04823356590743832
# XLMUSDT and VETUSDT: pval = 0.00687073593921787
# XLMUSDT and QTUMUSDT: pval = 0.014330981946964826
# XLMUSDT and BNBBUSD: pval = 0.014526293785396866
# XLMUSDT and ETHBUSD: pval = 0.02353451725142152
# XLMUSDT and VTHOUSDT: pval = 0.01993048019284742
# XLMUSDT and MKRUSDT: pval = 0.01687864419306237
# XLMUSDT and ONEUSDT: pval = 0.0006627304886383951
# XLMUSDT and STORJUSDT: pval = 0.006845541949944978
# XLMUSDT and SOLUSDT: pval = 1.1967646632548015e-07
# XLMUSDT and EGLDUSDT: pval = 0.00019862565068801697
# XLMUSDT and OXTUSDT: pval = 0.003609107168452255
# XLMUSDT and ZENUSDT: pval = 0.027612008779989
# XLMUSDT and FILUSDT: pval = 0.015674509370665363
# XLMUSDT and AAVEUSDT: pval = 0.021340522118604655
# XLMUSDT and SHIBUSDT: pval = 2.560996811732025e-08
# XLMUSDT and CRVUSDT: pval = 0.0002453176584994308
# ZRXUSDT and ONTUSDT: pval = 0.011899893288593047
# ZRXUSDT and BNBBUSD: pval = 0.006195051452013915
# ZRXUSDT and ETHBUSD: pval = 0.04315220612338288
# ZRXUSDT and STORJUSDT: pval = 0.03336030984505641
# ZRXUSDT and SOLUSDT: pval = 0.045585766196779426
# ZRXUSDT and EGLDUSDT: pval = 0.008937855609170535
# ZRXUSDT and ZENUSDT: pval = 0.00028200753045291854
# ZRXUSDT and FILUSDT: pval = 0.018939246449273212
# ZRXUSDT and AAVEUSDT: pval = 0.00161275837536924
# ZRXUSDT and SHIBUSDT: pval = 1.0879073800718028e-05
# ZRXUSDT and CRVUSDT: pval = 0.013195404969974199
# LINKUSD4 and RVNUSD4: pval = 0.03205284560348141
# LINKUSD4 and ALGOUSD4: pval = 0.00019337800575264645
# LINKUSD4 and IOTAUSD4: pval = 0.01441859564171387
# LINKUSD4 and ENJUSD4: pval = 0.008398720284056093
# LINKUSD4 and XTZUSD4: pval = 0.00040172780598772816
# LINKUSD4 and HBARUSD4: pval = 0.0023739921486774654
# LINKUSD4 and EOSUSD4: pval = 0.021614378065338984
# LINKUSD4 and MANAUSD4: pval = 0.024638359581928882
# LINKUSD4 and HNTUSD4: pval = 0.025189610798800832
# LINKUSD4 and ONEUSD4: pval = 0.00047905637701424036
# LINKUSD4 and STORJUSD4: pval = 0.034554763233543825
# LINKUSD4 and SOLUSD4: pval = 0.007033084582085948
# LINKUSD4 and EGLDUSD4: pval = 0.0037690799308541727
# LINKUSD4 and OXTUSD4: pval = 0.0026578362254041235
# LINKUSD4 and ZENUSD4: pval = 0.006785040718009853
# LINKUSD4 and FILUSD4: pval = 0.010925291672070195
# LINKUSD4 and AAVEUSD4: pval = 0.0013380782644797327
# LINKUSD4 and SUSHIUSD4: pval = 0.018781153160872793
# LINKUSD4 and CRVUSD4: pval = 0.031786886116144955
# RVNUSD4 and ALGOUSD4: pval = 0.009721762303394383
# RVNUSD4 and IOTAUSD4: pval = 0.014885798935349243
# RVNUSD4 and ENJUSD4: pval = 0.008176065073135876
# RVNUSD4 and XTZUSD4: pval = 0.022851503797441695
# RVNUSD4 and EOSUSD4: pval = 0.012729886815827042
# RVNUSD4 and MANAUSD4: pval = 0.038858264409197416
# RVNUSD4 and HNTUSD4: pval = 0.02837391462326573
# RVNUSD4 and ONEUSD4: pval = 0.018474789334467636
# RVNUSD4 and STORJUSD4: pval = 0.02534996672165022
# RVNUSD4 and SOLUSD4: pval = 0.017612600540197754
# RVNUSD4 and EGLDUSD4: pval = 0.02246430288008798
# RVNUSD4 and OXTUSD4: pval = 0.0031714911826669127
# RVNUSD4 and ZENUSD4: pval = 0.004330386931258125
# RVNUSD4 and FILUSD4: pval = 0.030795428932382782
# RVNUSD4 and GRTUSD4: pval = 0.01792526992472358
# RVNUSD4 and CRVUSD4: pval = 0.02400274626316658
# DASHUSD4 and ZECUSD4: pval = 0.039011237183443515
# DASHUSD4 and NEOUSD4: pval = 0.03469478041233253
# DASHUSD4 and QTUMUSD4: pval = 0.0009506461527689432
# DASHUSD4 and ENJUSD4: pval = 0.003169266777451741
# DASHUSD4 and XTZUSD4: pval = 0.031906336812490874
# DASHUSD4 and EOSUSD4: pval = 0.007106536011322222
# DASHUSD4 and DOGEUSD4: pval = 0.0014428751774192014
# DASHUSD4 and MANAUSD4: pval = 0.002719998344613452
# DASHUSD4 and HNTUSD4: pval = 0.01184218767997008
# DASHUSD4 and BANDUSD4: pval = 3.445563071499413e-05
# DASHUSD4 and STORJUSD4: pval = 0.02147774269287301
# DASHUSD4 and SOLUSD4: pval = 0.0008162205213120016
# DASHUSD4 and EGLDUSD4: pval = 0.013985339036714525
# DASHUSD4 and ZENUSD4: pval = 0.024084085704989436
# DASHUSD4 and FILUSD4: pval = 0.002720481628415578
# DASHUSD4 and AAVEUSD4: pval = 0.017860961808858294
# DASHUSD4 and GRTUSD4: pval = 0.0001724196722245159
# DASHUSD4 and ANKRUSD4: pval = 0.01991220867539923
# DASHUSD4 and CRVUSD4: pval = 0.0459757785253956
# ZECUSD4 and MKRUSD4: pval = 0.018902409287320423
# ALGOUSD4 and ICXUSD4: pval = 0.0056334033840911854
# ALGOUSD4 and ENJUSD4: pval = 5.7633915206649034e-05
# ALGOUSD4 and XTZUSD4: pval = 0.010993791120114586
# ALGOUSD4 and EOSUSD4: pval = 0.048353067408877085
# ALGOUSD4 and MANAUSD4: pval = 0.02242172402949713
# ALGOUSD4 and HNTUSD4: pval = 0.002350261149771782
# ALGOUSD4 and ONEUSD4: pval = 0.023416787572012054
# ALGOUSD4 and STORJUSD4: pval = 0.043571854973878756
# ALGOUSD4 and SOLUSD4: pval = 7.331894935086205e-05
# ALGOUSD4 and EGLDUSD4: pval = 0.003392216360521219
# ALGOUSD4 and OXTUSD4: pval = 6.756282237452537e-05
# ALGOUSD4 and GRTUSD4: pval = 0.006788403562286942
# ALGOUSD4 and ANKRUSD4: pval = 0.018697214485459402
# ALGOUSD4 and CRVUSD4: pval = 0.002770476364364243
# IOTAUSD4 and ENJUSD4: pval = 6.273784802108118e-06
# IOTAUSD4 and MANAUSD4: pval = 0.000553310956789485
# IOTAUSD4 and HNTUSD4: pval = 0.00021075476924778706
# IOTAUSD4 and ONEUSD4: pval = 0.002524857425056323
# IOTAUSD4 and STORJUSD4: pval = 0.012900091094793953
# IOTAUSD4 and SOLUSD4: pval = 0.012654968409678993
# IOTAUSD4 and EGLDUSD4: pval = 0.03317155311656474
# IOTAUSD4 and SUSHIUSD4: pval = 0.04700851794445102
# IOTAUSD4 and ANKRUSD4: pval = 0.0055335175319961745
# IOTAUSD4 and CRVUSD4: pval = 0.0001531646376931376
# BUSDUSD4 and WAVESUSD4: pval = 0.003269573703940053
# BUSDUSD4 and ATOMUSD4: pval = 0.002188137763103009
# BUSDUSD4 and NEOUSD4: pval = 0.001645879608579972
# BUSDUSD4 and QTUMUSD4: pval = 0.0016535006838500313
# BUSDUSD4 and ICXUSD4: pval = 0.0016643439632177068
# BUSDUSD4 and ENJUSD4: pval = 0.00279387616222984
# BUSDUSD4 and ONTUSD4: pval = 0.0017858923061999947
# BUSDUSD4 and ZILUSD4: pval = 0.0027320050379159564
# BUSDUSD4 and VETUSD4: pval = 0.0018103240801963063
# BUSDUSD4 and XTZUSD4: pval = 0.0012755014154946132
# BUSDUSD4 and HBARUSD4: pval = 0.001816159725719802
# BUSDUSD4 and OMGUSD4: pval = 0.0010596447299909815
# BUSDUSD4 and MATICUSD4: pval = 0.0031247453526470656
# BUSDUSD4 and EOSUSD4: pval = 0.0014998702276339568
# BUSDUSD4 and DOGEUSD4: pval = 0.001794466677768773
# BUSDUSD4 and KNCUSD4: pval = 0.004159296204251647
# BUSDUSD4 and VTHOUSD4: pval = 0.0016314573450626456
# BUSDUSD4 and USDCUSD4: pval = 0.0002595998464210175
# BUSDUSD4 and COMPUSD4: pval = 0.0015306578525430905
# BUSDUSD4 and MANAUSD4: pval = 0.0038938594528872784
# BUSDUSD4 and HNTUSD4: pval = 0.003288257108946911
# BUSDUSD4 and MKRUSD4: pval = 0.0024226553011184033
# BUSDUSD4 and DAIUSD4: pval = 0.0005263953953121328
# BUSDUSD4 and ONEUSD4: pval = 0.0027811237518078776
# BUSDUSD4 and BANDUSD4: pval = 0.001758058136609996
# BUSDUSD4 and STORJUSD4: pval = 0.0029194393147727975
# BUSDUSD4 and UNIUSD4: pval = 0.0013895287867459242
# BUSDUSD4 and SOLUSD4: pval = 0.002195699635290006
# BUSDUSD4 and EGLDUSD4: pval = 0.0022815361179959054
# BUSDUSD4 and PAXGUSD4: pval = 0.004574941322338324
# BUSDUSD4 and OXTUSD4: pval = 0.0019307748146442185
# BUSDUSD4 and ZENUSD4: pval = 0.001948650410733049
# BUSDUSD4 and FILUSD4: pval = 0.001316962721924837
# BUSDUSD4 and AAVEUSD4: pval = 0.0014182215110770894
# BUSDUSD4 and GRTUSD4: pval = 0.0019311615389760652
# BUSDUSD4 and SUSHIUSD4: pval = 0.0015730265218799487
# BUSDUSD4 and ANKRUSD4: pval = 0.002431851592420341
# BUSDUSD4 and CRVUSD4: pval = 0.0026585029663970337
# BUSDUSD4 and VITEUSDT: pval = 0.0051122500246984755
# BTCBUSD and SHIBUSDT: pval = 0.004201092583857567
# DOGEUSDT and NEOUSDT: pval = 0.0013564421149366362
# DOGEUSDT and VETUSDT: pval = 0.004805315554036201
# DOGEUSDT and QTUMUSDT: pval = 0.029444257567815713
# DOGEUSDT and ONTUSDT: pval = 0.023825668854399094
# DOGEUSDT and BNBBUSD: pval = 0.0022212345895964666
# DOGEUSDT and ETHBUSD: pval = 0.016337843467169606
# DOGEUSDT and VTHOUSDT: pval = 0.01628745093612316
# DOGEUSDT and ONEUSDT: pval = 0.034646009085342475
# DOGEUSDT and BANDUSDT: pval = 1.921040297942535e-08
# DOGEUSDT and STORJUSDT: pval = 0.0072587706445973645
# DOGEUSDT and SOLUSDT: pval = 0.03870687095335532
# DOGEUSDT and EGLDUSDT: pval = 0.0001968665069680901
# DOGEUSDT and OXTUSDT: pval = 0.016639938099685416
# DOGEUSDT and ZENUSDT: pval = 0.0063293053363911705
# DOGEUSDT and FILUSDT: pval = 0.018725610954866127
# DOGEUSDT and AAVEUSDT: pval = 0.0019688608249664365
# DOGEUSDT and SHIBUSDT: pval = 3.694183073176047e-06
# DOGEUSDT and CRVUSDT: pval = 0.002747437590680343
# WAVESUSD4 and ZILUSD4: pval = 0.0007326758739665778
# ATOMUSDT and BNBBUSD: pval = 0.017603657222661436
# ATOMUSDT and ETHBUSD: pval = 0.01570676149766642
# ATOMUSDT and SOLUSDT: pval = 0.04981136359704732
# ATOMUSDT and EGLDUSDT: pval = 0.005623423774550085
# ATOMUSDT and OXTUSDT: pval = 0.03028625561781861
# ATOMUSDT and SHIBUSDT: pval = 0.000615911436516017
# ATOMUSDT and CRVUSDT: pval = 0.0045220376151688954
# ATOMUSD4 and ENJUSD4: pval = 0.03365833577144485
# ATOMUSD4 and XTZUSD4: pval = 0.028605341332946885
# ATOMUSD4 and MATICUSD4: pval = 0.012798166714071316
# ATOMUSD4 and MANAUSD4: pval = 0.011822474450051492
# ATOMUSD4 and HNTUSD4: pval = 0.010995852910561628
# ATOMUSD4 and ONEUSD4: pval = 0.007131416480998541
# ATOMUSD4 and CRVUSD4: pval = 0.04840454785536006
# NEOUSDT and VETUSDT: pval = 0.008497219718167826
# NEOUSDT and QTUMUSDT: pval = 0.0014542253515307244
# NEOUSDT and ONTUSDT: pval = 0.006372863580268786
# NEOUSDT and BNBBUSD: pval = 9.105310889304822e-06
# NEOUSDT and ETHBUSD: pval = 0.00748631562206597
# NEOUSDT and KNCUSDT: pval = 0.03163394331681536
# NEOUSDT and COMPUSDT: pval = 0.008462323326749588
# NEOUSDT and ONEUSDT: pval = 0.0073709445270091455
# NEOUSDT and STORJUSDT: pval = 0.016873224536755015
# NEOUSDT and SOLUSDT: pval = 0.0036556315391434303
# NEOUSDT and EGLDUSDT: pval = 0.003138539375329925
# NEOUSDT and OXTUSDT: pval = 1.3140104600487915e-08
# NEOUSDT and ZENUSDT: pval = 0.0010802027004189793
# NEOUSDT and BTCUSDC: pval = 0.01548967218218968
# NEOUSDT and AAVEUSDT: pval = 0.0033296446239496906
# NEOUSDT and SHIBUSDT: pval = 4.228289831848055e-10
# NEOUSDT and CRVUSDT: pval = 0.0027598950974767737
# NEOUSD4 and QTUMUSD4: pval = 0.007484279369325418
# NEOUSD4 and ENJUSD4: pval = 0.000576573454804498
# NEOUSD4 and ONTUSD4: pval = 0.010651307550098939
# NEOUSD4 and VETUSD4: pval = 0.01846710085771818
# NEOUSD4 and DOGEUSD4: pval = 0.009191505327248864
# NEOUSD4 and COMPUSD4: pval = 0.016016170842763883
# NEOUSD4 and MANAUSD4: pval = 0.001072680788391361
# NEOUSD4 and HNTUSD4: pval = 0.002949781982684713
# NEOUSD4 and BANDUSD4: pval = 0.00599407882937354
# NEOUSD4 and SOLUSD4: pval = 0.0001898816073656223
# NEOUSD4 and EGLDUSD4: pval = 0.020310734597000512
# NEOUSD4 and OXTUSD4: pval = 9.892158432658566e-09
# NEOUSD4 and ZENUSD4: pval = 0.0020029950624102684
# NEOUSD4 and AAVEUSD4: pval = 0.017890671271932633
# NEOUSD4 and GRTUSD4: pval = 0.016066610652744055
# NEOUSD4 and ANKRUSD4: pval = 0.018406657970363557
# NEOUSD4 and CRVUSD4: pval = 0.03188275736103164
# VETUSDT and QTUMUSDT: pval = 0.0004560827861368644
# VETUSDT and ONTUSDT: pval = 0.0071053562973775585
# VETUSDT and BNBBUSD: pval = 0.04187797990672281
# VETUSDT and VTHOUSDT: pval = 5.373843939630041e-07
# VETUSDT and COMPUSDT: pval = 0.0012196438809283976
# VETUSDT and ONEUSDT: pval = 0.03524793177699067
# VETUSDT and BANDUSDT: pval = 0.0018614689978402018
# VETUSDT and STORJUSDT: pval = 0.011661027090370917
# VETUSDT and UNIUSDT: pval = 0.0046429985777616195
# VETUSDT and SOLUSDT: pval = 0.0027015110346818656
# VETUSDT and EGLDUSDT: pval = 0.0005047287646780238
# VETUSDT and ZENUSDT: pval = 0.00030560218131584925
# VETUSDT and FILUSDT: pval = 1.0692551042855376e-07
# VETUSDT and AAVEUSDT: pval = 0.012335089130646374
# VETUSDT and SHIBUSDT: pval = 3.978570075467524e-14
# VETUSDT and CRVUSDT: pval = 0.004085023828201892
# QTUMUSDT and ONTUSDT: pval = 0.022513736619356895
# QTUMUSDT and BNBBUSD: pval = 0.0037150275952438174
# QTUMUSDT and VTHOUSDT: pval = 3.46640393027579e-05
# QTUMUSDT and COMPUSDT: pval = 0.0007958886707251667
# QTUMUSDT and ONEUSDT: pval = 0.02289033995299228
# QTUMUSDT and BANDUSDT: pval = 0.016317576677889262
# QTUMUSDT and STORJUSDT: pval = 0.009141901663782068
# QTUMUSDT and UNIUSDT: pval = 0.008713010315016348
# QTUMUSDT and SOLUSDT: pval = 0.00528525690554861
# QTUMUSDT and EGLDUSDT: pval = 0.008470689100261209
# QTUMUSDT and ZENUSDT: pval = 0.0006473986589839791
# QTUMUSDT and FILUSDT: pval = 6.0617241150825924e-05
# QTUMUSDT and AAVEUSDT: pval = 0.001344933179920357
# QTUMUSDT and SHIBUSDT: pval = 2.2699598253372556e-11
# QTUMUSDT and CRVUSDT: pval = 0.0034841405610530176
# QTUMUSD4 and ICXUSD4: pval = 0.0007889789736208972
# QTUMUSD4 and ENJUSD4: pval = 0.015034722923748956
# QTUMUSD4 and VETUSD4: pval = 0.013042759229496858
# QTUMUSD4 and OMGUSD4: pval = 0.002817154092423715
# QTUMUSD4 and EOSUSD4: pval = 0.0017517632659310046
# QTUMUSD4 and DOGEUSD4: pval = 0.016880153611918584
# QTUMUSD4 and VTHOUSD4: pval = 0.00026704309860602483
# QTUMUSD4 and MANAUSD4: pval = 0.014879026300102552
# QTUMUSD4 and SOLUSD4: pval = 0.046051189441977225
# QTUMUSD4 and EGLDUSD4: pval = 0.017871416188269575
# QTUMUSD4 and ZENUSD4: pval = 0.004107155467222321
# QTUMUSD4 and FILUSD4: pval = 0.0014839083881881996
# QTUMUSD4 and GRTUSD4: pval = 0.007741889595048932
# QTUMUSD4 and SUSHIUSD4: pval = 0.013063443312655965
# ICXUSD4 and ENJUSD4: pval = 0.005530718679654277
# ICXUSD4 and VETUSD4: pval = 1.054731655002479e-05
# ICXUSD4 and XTZUSD4: pval = 0.009099064921407747
# ICXUSD4 and DOGEUSD4: pval = 0.0026170767988281424
# ICXUSD4 and VTHOUSD4: pval = 2.780684540806642e-09
# ICXUSD4 and COMPUSD4: pval = 0.005295674615152329
# ICXUSD4 and MANAUSD4: pval = 0.004160537001415527
# ICXUSD4 and HNTUSD4: pval = 0.0036859498722510097
# ICXUSD4 and BANDUSD4: pval = 0.000266536403162812
# ICXUSD4 and STORJUSD4: pval = 0.031170371426345996
# ICXUSD4 and SOLUSD4: pval = 0.0005784422022482639
# ICXUSD4 and EGLDUSD4: pval = 0.018871035158098973
# ICXUSD4 and OXTUSD4: pval = 0.015886619910376865
# ICXUSD4 and ZENUSD4: pval = 0.009361289930575417
# ICXUSD4 and FILUSD4: pval = 0.0008976980971669139
# ICXUSD4 and AAVEUSD4: pval = 0.01211666673603131
# ICXUSD4 and GRTUSD4: pval = 4.472564426108687e-05
# ICXUSD4 and SUSHIUSD4: pval = 0.008355697952036641
# ICXUSD4 and ANKRUSD4: pval = 0.013045512447745143
# ICXUSD4 and CRVUSD4: pval = 0.019043386326876608
# ENJUSD4 and ONTUSD4: pval = 0.00701720995929252
# ENJUSD4 and XTZUSD4: pval = 0.009300711033820498
# ENJUSD4 and HBARUSD4: pval = 0.0025274137857746568
# ENJUSD4 and EOSUSD4: pval = 0.011750937030530217
# ENJUSD4 and VTHOUSD4: pval = 0.03647853486604073
# ENJUSD4 and COMPUSD4: pval = 0.02659020531016344
# ENJUSD4 and MKRUSD4: pval = 0.010428228597372887
# ENJUSD4 and ONEUSD4: pval = 0.00013864348398401978
# ENJUSD4 and BANDUSD4: pval = 0.026387625031475775
# ENJUSD4 and STORJUSD4: pval = 0.004808710282322759
# ENJUSD4 and UNIUSD4: pval = 0.032315905087106356
# ENJUSD4 and SOLUSD4: pval = 0.0351506379470171
# ENJUSD4 and EGLDUSD4: pval = 0.01211834853947275
# ENJUSD4 and OXTUSD4: pval = 0.004540731242832586
# ENJUSD4 and ZENUSD4: pval = 0.019157416551088925
# ENJUSD4 and FILUSD4: pval = 0.03144001583118408
# ENJUSD4 and AAVEUSD4: pval = 0.007015821219448913
# ENJUSD4 and SUSHIUSD4: pval = 0.011510233221657555
# ENJUSD4 and ANKRUSD4: pval = 0.022596732751394392
# ENJUSD4 and CRVUSD4: pval = 0.005638126455476516
# ONTUSD4 and XTZUSD4: pval = 0.010445634906926788
# ONTUSD4 and MATICUSD4: pval = 0.027531304336842897
# ONTUSD4 and EOSUSD4: pval = 0.0008839112848395346
# ONTUSD4 and MANAUSD4: pval = 0.0008185671431551485
# ONTUSD4 and HNTUSD4: pval = 0.003061258527024928
# ONTUSD4 and ONEUSD4: pval = 0.0337635056358244
# ONTUSD4 and SOLUSD4: pval = 0.001170854452181211
# ONTUSD4 and EGLDUSD4: pval = 0.0049811997024863655
# ONTUSD4 and OXTUSD4: pval = 0.01927847000246708
# ONTUSD4 and ZENUSD4: pval = 0.03033486723293726
# ONTUSD4 and AAVEUSD4: pval = 0.011814078326452418
# ONTUSD4 and GRTUSD4: pval = 6.69385642085146e-05
# ONTUSD4 and SUSHIUSD4: pval = 0.015074040298538071
# ONTUSD4 and ANKRUSD4: pval = 0.03820793340956618
# ONTUSD4 and CRVUSD4: pval = 0.023224671168649843
# ONTUSDT and BNBBUSD: pval = 5.8846283058296405e-05
# ONTUSDT and ONEUSDT: pval = 0.02142285727833742
# ONTUSDT and STORJUSDT: pval = 0.041191726498074024
# ONTUSDT and SOLUSDT: pval = 7.797147377627334e-05
# ONTUSDT and EGLDUSDT: pval = 9.553098655999448e-05
# ONTUSDT and OXTUSDT: pval = 0.002525925723750609
# ONTUSDT and ZENUSDT: pval = 0.003976540340016036
# ONTUSDT and FILUSDT: pval = 0.0018162714006488604
# ONTUSDT and AAVEUSDT: pval = 0.0006167622999943202
# ONTUSDT and SHIBUSDT: pval = 3.68478236647769e-13
# ONTUSDT and CRVUSDT: pval = 0.0013234436851998607
# ZILUSD4 and OMGUSD4: pval = 0.03273529558589367
# ZILUSD4 and VTHOUSD4: pval = 0.048770193297636086
# ZILUSD4 and STORJUSD4: pval = 0.03925823246098765
# ZILUSD4 and OXTUSD4: pval = 0.03517506290173098
# ZILUSD4 and ANKRUSD4: pval = 0.031685388228801015
# ZILBUSD and SHIBBUSD: pval = 0.0027979688681190732
# VETUSD4 and XTZUSD4: pval = 0.008830946154301647
# VETUSD4 and OMGUSD4: pval = 0.03284907940780129
# VETUSD4 and EOSUSD4: pval = 0.0010893160158042172
# VETUSD4 and VTHOUSD4: pval = 4.862588160474855e-06
# VETUSD4 and COMPUSD4: pval = 0.0008159005846645951
# VETUSD4 and MANAUSD4: pval = 0.02222560217255855
# VETUSD4 and BANDUSD4: pval = 0.026992617308112483
# VETUSD4 and UNIUSD4: pval = 0.007917601489158967
# VETUSD4 and SOLUSD4: pval = 0.016405353103257973
# VETUSD4 and EGLDUSD4: pval = 0.012028726687787532
# VETUSD4 and ZENUSD4: pval = 0.004169589831617715
# VETUSD4 and FILUSD4: pval = 0.00037397630384439613
# VETUSD4 and AAVEUSD4: pval = 0.014147870860430555
# VETUSD4 and GRTUSD4: pval = 0.0027071468194614047
# VETUSD4 and SUSHIUSD4: pval = 0.019127729019373537
# VETUSD4 and ANKRUSD4: pval = 0.02054345304191286
# BNBBUSD and VTHOUSDT: pval = 0.027510205283822194
# BNBBUSD and COMPUSDT: pval = 0.023406208940986672
# BNBBUSD and ONEUSDT: pval = 0.007594015593713714
# BNBBUSD and BANDUSDT: pval = 0.021282113858278048
# BNBBUSD and UNIUSDT: pval = 0.030505109567096796
# BNBBUSD and SOLUSDT: pval = 0.025549236900174577
# BNBBUSD and ZENUSDT: pval = 0.029218079628941847
# BNBBUSD and FILUSDT: pval = 0.0065223706903303124
# BNBBUSD and AAVEUSDT: pval = 0.016073719802713195
# BNBBUSD and SHIBUSDT: pval = 0.013499191706597677
# ETHBUSD and VTHOUSDT: pval = 0.018398489633890625
# ETHBUSD and ONEUSDT: pval = 0.044571834932427765
# ETHBUSD and OXTUSDT: pval = 0.026548509986374737
# ETHBUSD and FILUSDT: pval = 0.011787312859884736
# ETHBUSD and SHIBUSDT: pval = 0.026857644854429083
# ALGOBUSD and EOSBUSD: pval = 0.03593123763250669
# ALGOBUSD and SHIBBUSD: pval = 4.188586955337109e-06
# XTZUSD4 and HBARUSD4: pval = 0.001700528103117969
# XTZUSD4 and MATICUSD4: pval = 0.0010421572369903505
# XTZUSD4 and EOSUSD4: pval = 0.029596566517810466
# XTZUSD4 and DOGEUSD4: pval = 0.0011851236662516864
# XTZUSD4 and VTHOUSD4: pval = 0.02855859452248633
# XTZUSD4 and COMPUSD4: pval = 0.03177957474498068
# XTZUSD4 and MANAUSD4: pval = 0.00014966071574228532
# XTZUSD4 and HNTUSD4: pval = 0.00013851791027457512
# XTZUSD4 and MKRUSD4: pval = 0.00027049750184357534
# XTZUSD4 and ONEUSD4: pval = 1.0896228204922451e-07
# XTZUSD4 and BANDUSD4: pval = 0.014876377498739267
# XTZUSD4 and STORJUSD4: pval = 0.0015999207345731418
# XTZUSD4 and SOLUSD4: pval = 3.458317815348879e-05
# XTZUSD4 and EGLDUSD4: pval = 0.003476326347688881
# XTZUSD4 and PAXGUSD4: pval = 0.023815785412070033
# XTZUSD4 and OXTUSD4: pval = 4.914307939292588e-05
# XTZUSD4 and ZENUSD4: pval = 0.002785594570584196
# XTZUSD4 and AAVEUSD4: pval = 0.00028318831962696224
# XTZUSD4 and GRTUSD4: pval = 7.278799166759077e-05
# XTZUSD4 and SUSHIUSD4: pval = 0.020948300172157222
# XTZUSD4 and ANKRUSD4: pval = 0.000167167026177375
# XTZUSD4 and CRVUSD4: pval = 0.0003519144560559461
# XTZBUSD and MATICBUSD: pval = 0.0006994203665146282
# XTZBUSD and EOSBUSD: pval = 0.025206722885722965
# XTZBUSD and SHIBBUSD: pval = 8.927084778940271e-09
# HBARUSD4 and MATICUSD4: pval = 0.045940147452238816
# HBARUSD4 and MANAUSD4: pval = 0.0016458270891071005
# HBARUSD4 and HNTUSD4: pval = 0.005931417234660504
# HBARUSD4 and ONEUSD4: pval = 0.00817326877253263
# HBARUSD4 and STORJUSD4: pval = 0.02177818978202838
# HBARUSD4 and SOLUSD4: pval = 0.012939026093283526
# HBARUSD4 and EGLDUSD4: pval = 0.004641774779067096
# HBARUSD4 and ZENUSD4: pval = 0.01102787229961877
# HBARUSD4 and AAVEUSD4: pval = 0.0062362757300454975
# HBARUSD4 and ANKRUSD4: pval = 0.000895322039237901
# HBARUSD4 and CRVUSD4: pval = 0.0072310158284639514
# HBARBUSD and ONEBUSD: pval = 0.0013337888911936283
# OMGUSD4 and DOGEUSD4: pval = 0.02875015004206433
# OMGUSD4 and VTHOUSD4: pval = 0.030984016299691327
# OMGUSD4 and COMPUSD4: pval = 0.04636836359652892
# OMGUSD4 and MANAUSD4: pval = 0.01992497616888818
# OMGUSD4 and HNTUSD4: pval = 0.004556950458081217
# OMGUSD4 and ONEUSD4: pval = 0.04304310077060965
# OMGUSD4 and BANDUSD4: pval = 0.03707593697023853
# OMGUSD4 and STORJUSD4: pval = 0.024599713029928246
# OMGUSD4 and SOLUSD4: pval = 0.0038289066144919417
# OMGUSD4 and EGLDUSD4: pval = 0.004299304655083679
# OMGUSD4 and ZENUSD4: pval = 0.0001366828713906093
# OMGUSD4 and FILUSD4: pval = 0.004606783876822757
# OMGUSD4 and AAVEUSD4: pval = 0.02198182897947826
# OMGUSD4 and GRTUSD4: pval = 0.016513029049186778
# OMGUSD4 and ANKRUSD4: pval = 0.048650219383757354
# OMGUSD4 and CRVUSD4: pval = 0.008552357032982195
# OMGBUSD and MATICBUSD: pval = 0.014479037501768576
# OMGBUSD and SHIBBUSD: pval = 4.708725795614312e-09
# MATICUSD4 and CRVUSD4: pval = 0.03200713679743471
# ADABTC and KNCUSDT: pval = 0.00647362577758225
# ADABTC and ONEUSDT: pval = 0.000503045203790016
# ADABTC and STORJUSDT: pval = 0.002550289443113663
# ADABTC and PAXGUSDT: pval = 0.03043447238593803
# ADABTC and OXTUSDT: pval = 0.019502578358923568
# ADABTC and SHIBUSDT: pval = 0.019354873834107757
# REPBUSD and REPUSD: pval = 0.0
# EOSBUSD and SHIBBUSD: pval = 5.1673022087238804e-08
# EOSUSD4 and DOGEUSD4: pval = 0.03285249381555757
# EOSUSD4 and VTHOUSD4: pval = 0.002416399295734288
# EOSUSD4 and COMPUSD4: pval = 0.003299836803378827
# EOSUSD4 and MANAUSD4: pval = 0.002002008719137724
# EOSUSD4 and HNTUSD4: pval = 0.004333123492809235
# EOSUSD4 and MKRUSD4: pval = 0.04511727098349882
# EOSUSD4 and ONEUSD4: pval = 0.003902988474989553
# EOSUSD4 and BANDUSD4: pval = 0.016952933171665546
# EOSUSD4 and SOLUSD4: pval = 0.026873781098005024
# EOSUSD4 and EGLDUSD4: pval = 0.0011898976031118036
# EOSUSD4 and ZENUSD4: pval = 0.006729296730706243
# EOSUSD4 and AAVEUSD4: pval = 0.0014211418388485268
# EOSUSD4 and GRTUSD4: pval = 0.004350138861059834
# EOSUSD4 and ANKRUSD4: pval = 0.008342004713092706
# EOSUSD4 and CRVUSD4: pval = 0.028822852096405015
# DOGEUSD4 and BANDUSD4: pval = 7.982616403229988e-06
# DOGEUSD4 and EGLDUSD4: pval = 0.010288540337680337
# DOGEUSD4 and OXTUSD4: pval = 0.017217961667215537
# DOGEUSD4 and ZENUSD4: pval = 0.021479866168144863
# DOGEUSD4 and AAVEUSD4: pval = 0.025106570157960396
# DOGEUSD4 and GRTUSD4: pval = 0.025837420004117005
# DOGEUSD4 and ANKRUSD4: pval = 0.03854911419305119
# VTHOUSDT and COMPUSDT: pval = 0.021593176830618194
# VTHOUSDT and ONEUSDT: pval = 0.009234057109460295
# VTHOUSDT and STORJUSDT: pval = 0.012977276444918643
# VTHOUSDT and UNIUSDT: pval = 0.042799508485554756
# VTHOUSDT and SOLUSDT: pval = 1.1220183871712409e-05
# VTHOUSDT and EGLDUSDT: pval = 0.0004089371487015225
# VTHOUSDT and OXTUSDT: pval = 0.0019445254763490074
# VTHOUSDT and ZENUSDT: pval = 0.004384955008977389
# VTHOUSDT and FILUSDT: pval = 6.8267596652413545e-06
# VTHOUSDT and AAVEUSDT: pval = 0.003789095651009744
# VTHOUSDT and SHIBUSDT: pval = 7.381427448815247e-10
# VTHOUSDT and CRVUSDT: pval = 0.00023440861014651949
# VTHOUSD4 and MANAUSD4: pval = 0.003962417251060714
# VTHOUSD4 and HNTUSD4: pval = 0.03988022672507821
# VTHOUSD4 and SOLUSD4: pval = 0.00012618839612173443
# VTHOUSD4 and EGLDUSD4: pval = 0.014308671063417721
# VTHOUSD4 and OXTUSD4: pval = 0.030291453471063528
# VTHOUSD4 and ZENUSD4: pval = 0.0008716942583417434
# VTHOUSD4 and FILUSD4: pval = 4.646039653775352e-05
# VTHOUSD4 and AAVEUSD4: pval = 0.03868609431723541
# VTHOUSD4 and GRTUSD4: pval = 2.8429898176778658e-05
# VTHOUSD4 and SUSHIUSD4: pval = 0.007014909563645996
# VTHOUSD4 and ANKRUSD4: pval = 0.023977936750793665
# VTHOUSD4 and CRVUSD4: pval = 0.02904883613901256
# USDCUSD4 and COMPUSD4: pval = 0.00039124960483643916
# USDCUSD4 and MANAUSD4: pval = 0.0006098496307164035
# USDCUSD4 and HNTUSD4: pval = 0.0005186521066737985
# USDCUSD4 and MKRUSD4: pval = 0.0005120368591027178
# USDCUSD4 and DAIUSD4: pval = 3.7397122693023464e-09
# USDCUSD4 and ONEUSD4: pval = 6.777183748342062e-09
# USDCUSD4 and BANDUSD4: pval = 0.0003289920997295361
# USDCUSD4 and STORJUSD4: pval = 0.00047016927363861425
# USDCUSD4 and UNIUSD4: pval = 0.0003466914757982869
# USDCUSD4 and SOLUSD4: pval = 0.0004239037756211301
# USDCUSD4 and EGLDUSD4: pval = 0.0004463487468375369
# USDCUSD4 and PAXGUSD4: pval = 0.0006821378641740147
# USDCUSD4 and OXTUSD4: pval = 0.0004171984702389645
# USDCUSD4 and ZENUSD4: pval = 0.00043730065041801155
# USDCUSD4 and FILUSD4: pval = 0.0003836978263647048
# USDCUSD4 and AAVEUSD4: pval = 0.0003461300901276026
# USDCUSD4 and GRTUSD4: pval = 0.0004187657146486475
# USDCUSD4 and SUSHIUSD4: pval = 0.0003648642240597116
# USDCUSD4 and ANKRUSD4: pval = 0.0004545104103579185
# USDCUSD4 and CRVUSD4: pval = 5.986431099257862e-09
# USDCUSD4 and VITEUSDT: pval = 0.0007044321756911069
# COMPUSDT and ONEUSDT: pval = 0.014635115652545144
# COMPUSDT and STORJUSDT: pval = 0.0036789029537861832
# COMPUSDT and SOLUSDT: pval = 0.001683865656726541
# COMPUSDT and EGLDUSDT: pval = 0.00022323675874309928
# COMPUSDT and OXTUSDT: pval = 0.009608931817940904
# COMPUSDT and ZENUSDT: pval = 0.000282894277415014
# COMPUSDT and FILUSDT: pval = 1.8709712910007304e-07
# COMPUSDT and AAVEUSDT: pval = 0.02528986427325146
# COMPUSDT and SHIBUSDT: pval = 3.813295492781596e-14
# COMPUSDT and CRVUSDT: pval = 0.0010803436615067943
# COMPUSD4 and MANAUSD4: pval = 0.004290215022645497
# COMPUSD4 and HNTUSD4: pval = 0.012649444236227908
# COMPUSD4 and BANDUSD4: pval = 0.025986028856678955
# COMPUSD4 and STORJUSD4: pval = 0.015737507901026425
# COMPUSD4 and SOLUSD4: pval = 0.021875020583315617
# COMPUSD4 and EGLDUSD4: pval = 0.01874570624477599
# COMPUSD4 and OXTUSD4: pval = 0.0006866532302472564
# COMPUSD4 and ZENUSD4: pval = 0.007983900738715854
# COMPUSD4 and FILUSD4: pval = 0.00024413606388484383
# COMPUSD4 and AAVEUSD4: pval = 0.01121474617231906
# COMPUSD4 and GRTUSD4: pval = 0.0007790578869648332
# COMPUSD4 and ANKRUSD4: pval = 0.04441595576829561
# COMPUSD4 and CRVUSD4: pval = 0.029154128567888994
# MANAUSD4 and HNTUSD4: pval = 0.011766906355138749
# MANAUSD4 and MKRUSD4: pval = 0.0018822379728885724
# MANAUSD4 and ONEUSD4: pval = 0.0007713684442462479
# MANAUSD4 and STORJUSD4: pval = 0.038207789500247086
# MANAUSD4 and SOLUSD4: pval = 0.04609253621214153
# MANAUSD4 and EGLDUSD4: pval = 0.029980832099548712
# MANAUSD4 and OXTUSD4: pval = 0.010337469270849421
# MANAUSD4 and ANKRUSD4: pval = 0.02846311595907835
# MANAUSD4 and CRVUSD4: pval = 0.003476015912082944
# MANAUSD4 and VITEUSDT: pval = 0.04723012698269868
# HNTUSD4 and MKRUSD4: pval = 0.007790991557880323
# HNTUSD4 and ONEUSD4: pval = 0.014807460699737075
# HNTUSD4 and STORJUSD4: pval = 0.0025444032757061205
# HNTUSD4 and SOLUSD4: pval = 0.042048619079015
# HNTUSD4 and OXTUSD4: pval = 0.007862438890680636
# HNTUSD4 and ANKRUSD4: pval = 0.008043775849159674
# HNTUSD4 and CRVUSD4: pval = 0.0003014706059165278
# HNTUSDT and HNTUSD: pval = 1.7263918036582304e-05
# MKRUSD4 and STORJUSD4: pval = 0.02652406198495391
# MKRUSD4 and EGLDUSD4: pval = 0.03160881025848179
# MKRUSD4 and ZENUSD4: pval = 0.008958868986263033
# MKRUSD4 and ANKRUSD4: pval = 0.011584183700681636
# MKRUSD4 and CRVUSD4: pval = 0.028655713811031498
# MKRUSDT and SHIBUSDT: pval = 0.003822385543172749
# DAIUSD4 and ONEUSD4: pval = 2.3207947209851418e-11
# DAIUSD4 and BANDUSD4: pval = 4.265483048394561e-11
# DAIUSD4 and STORJUSD4: pval = 9.498928927241297e-11
# DAIUSD4 and UNIUSD4: pval = 2.8861731624483375e-11
# DAIUSD4 and SOLUSD4: pval = 3.7748244793453674e-11
# DAIUSD4 and EGLDUSD4: pval = 9.483920886147031e-11
# DAIUSD4 and PAXGUSD4: pval = 5.099420786982539e-10
# DAIUSD4 and OXTUSD4: pval = 4.4490031836419947e-11
# DAIUSD4 and ZENUSD4: pval = 5.877119409437451e-11
# DAIUSD4 and FILUSD4: pval = 3.358429188616404e-11
# DAIUSD4 and AAVEUSD4: pval = 2.4492266890497415e-11
# DAIUSD4 and GRTUSD4: pval = 4.4124404482854024e-11
# DAIUSD4 and SUSHIUSD4: pval = 1.958285307193059e-11
# DAIUSD4 and ANKRUSD4: pval = 7.226699364469555e-11
# DAIUSD4 and CRVUSD4: pval = 3.9127705866793915e-11
# DAIUSD4 and VITEUSDT: pval = 6.413987462519682e-11
# ONEUSDT and STORJUSDT: pval = 0.00750718974906575
# ONEUSDT and SOLUSDT: pval = 0.027690496708064265
# ONEUSDT and EGLDUSDT: pval = 8.243874541021187e-05
# ONEUSDT and ZENUSDT: pval = 0.017642010567177797
# ONEUSDT and SHIBUSDT: pval = 0.003888851017571158
# ONEUSDT and CRVUSDT: pval = 0.0028787679280743014
# ONEUSD4 and EGLDUSD4: pval = 0.003751202328735661
# ONEUSD4 and ANKRUSD4: pval = 0.022963770752070525
# ONEUSD4 and CRVUSD4: pval = 0.026256873299653104
# BANDUSDT and STORJUSDT: pval = 0.02377262017236955
# BANDUSDT and SOLUSDT: pval = 0.016063590767055484
# BANDUSDT and EGLDUSDT: pval = 0.001288948937595532
# BANDUSDT and OXTUSDT: pval = 0.02492059601297326
# BANDUSDT and ZENUSDT: pval = 0.0008897146293628438
# BANDUSDT and FILUSDT: pval = 7.368449238375989e-06
# BANDUSDT and AAVEUSDT: pval = 0.03071845654015542
# BANDUSDT and SHIBUSDT: pval = 1.8075164474140182e-10
# BANDUSDT and CRVUSDT: pval = 0.0008807905321623364
# BANDUSD4 and EGLDUSD4: pval = 0.03919033239251454
# BANDUSD4 and ZENUSD4: pval = 0.03740467901177991
# BANDUSD4 and FILUSD4: pval = 0.01662351196574854
# BANDUSD4 and AAVEUSD4: pval = 0.03706513912237423
# BANDUSD4 and GRTUSD4: pval = 0.005483680758482155
# BANDUSD4 and SUSHIUSD4: pval = 0.010164113380476061
# BANDUSD4 and CRVUSD4: pval = 0.018113268236584587
# STORJUSDT and SOLUSDT: pval = 0.007969436902619944
# STORJUSDT and EGLDUSDT: pval = 0.028484861412202873
# STORJUSDT and OXTUSDT: pval = 0.012460060808630649
# STORJUSDT and FILUSDT: pval = 0.010299575596460362
# STORJUSDT and AAVEUSDT: pval = 0.019533689936416597
# STORJUSDT and SHIBUSDT: pval = 0.0030420946804701698
# STORJUSDT and CRVUSDT: pval = 0.0014520038485878386
# STORJUSD4 and GRTUSD4: pval = 0.04438513205785856
# STORJUSD4 and CRVUSD4: pval = 0.03187789804246643
# UNIUSD4 and SOLUSD4: pval = 0.00014206432057410284
# UNIUSD4 and ZENUSD4: pval = 0.010143057321408792
# UNIUSD4 and FILUSD4: pval = 0.0422352828388987
# UNIUSD4 and GRTUSD4: pval = 0.019487963922264692
# UNIUSD4 and SUSHIUSD4: pval = 0.021016320849061982
# UNIUSD4 and ANKRUSD4: pval = 0.024508746900513835
# UNIUSD4 and CRVUSD4: pval = 0.0013066444258481756
# UNIUSDT and SOLUSDT: pval = 0.000492185607713098
# UNIUSDT and EGLDUSDT: pval = 0.008957093725414596
# UNIUSDT and OXTUSDT: pval = 0.01771812272096556
# UNIUSDT and ZENUSDT: pval = 0.0017109500682220393
# UNIUSDT and FILUSDT: pval = 0.023602755702120354
# UNIUSDT and SHIBUSDT: pval = 1.499491652474307e-08
# UNIUSDT and CRVUSDT: pval = 1.829586137818262e-05
# SOLUSD4 and EGLDUSD4: pval = 0.0009327864712292745
# SOLUSD4 and OXTUSD4: pval = 0.0001761239774780042
# SOLUSD4 and ZENUSD4: pval = 9.593382787182895e-06
# SOLUSD4 and FILUSD4: pval = 0.006405610541919463
# SOLUSD4 and AAVEUSD4: pval = 0.0031031709955426498
# SOLUSD4 and SUSHIUSD4: pval = 0.008486797709807804
# SOLUSD4 and ANKRUSD4: pval = 0.04093134912020682
# SOLUSDT and EGLDUSDT: pval = 9.12170447806755e-05
# SOLUSDT and ZENUSDT: pval = 2.8976048002768497e-08
# SOLUSDT and FILUSDT: pval = 0.00033410121119594474
# SOLUSDT and AAVEUSDT: pval = 5.09142429182325e-05
# SOLUSDT and SHIBUSDT: pval = 0.000608347613691053
# SOLUSDT and CRVUSDT: pval = 0.005526966900230057
# LINKBTC and SHIBUSDT: pval = 0.00015205670114070468
# EGLDUSDT and OXTUSDT: pval = 0.0056792465174200025
# EGLDUSDT and ZENUSDT: pval = 0.001236781105300202
# EGLDUSDT and FILUSDT: pval = 0.0033188644303721176
# EGLDUSDT and AAVEUSDT: pval = 0.00025909808917590893
# EGLDUSDT and SHIBUSDT: pval = 3.40378514048938e-08
# EGLDUSDT and CRVUSDT: pval = 0.0008936202472885211
# EGLDUSD4 and OXTUSD4: pval = 2.7535367191929653e-05
# EGLDUSD4 and FILUSD4: pval = 0.0288003418922231
# EGLDUSD4 and GRTUSD4: pval = 0.002136448099524673
# EGLDUSD4 and SUSHIUSD4: pval = 0.04333324734661956
# EGLDUSD4 and ANKRUSD4: pval = 0.004770076485128908
# EGLDUSD4 and CRVUSD4: pval = 0.018109791673665557
# OXTUSDT and ZENUSDT: pval = 8.224819505818606e-05
# OXTUSDT and AAVEUSDT: pval = 0.028643354604881637
# OXTUSDT and SHIBUSDT: pval = 2.459968390623488e-09
# OXTUSDT and CRVUSDT: pval = 0.022460666354521694
# OXTUSD4 and ZENUSD4: pval = 7.310139118254865e-05
# OXTUSD4 and AAVEUSD4: pval = 0.009824842194328755
# OXTUSD4 and GRTUSD4: pval = 3.077951399339405e-10
# OXTUSD4 and SUSHIUSD4: pval = 0.018740400991557743
# OXTUSD4 and CRVUSD4: pval = 0.04576018283562897
# ZENUSDT and FILUSDT: pval = 0.0001375228628120875
# ZENUSDT and AAVEUSDT: pval = 0.0014917744745255013
# ZENUSDT and SHIBUSDT: pval = 3.0812932567449696e-08
# ZENUSDT and CRVUSDT: pval = 0.015468158484273577
# ZENUSD4 and FILUSD4: pval = 0.003056455354917325
# ZENUSD4 and AAVEUSD4: pval = 0.015488029778863025
# ZENUSD4 and GRTUSD4: pval = 1.939525941491662e-05
# ZENUSD4 and SUSHIUSD4: pval = 0.03800743070614725
# ZENUSD4 and CRVUSD4: pval = 0.035510490218336514
# BTCUSDC and FILUSDT: pval = 0.027983792517888705
# BTCUSDC and SHIBUSDT: pval = 0.0037782384600010405
# FILUSDT and AAVEUSDT: pval = 0.0010653189242753123
# FILUSDT and SHIBUSDT: pval = 2.985664466483451e-18
# FILUSDT and CRVUSDT: pval = 5.7604439575959055e-06
# FILUSDT and USDTUSD: pval = 0.017515058531759227
# FILUSD4 and AAVEUSD4: pval = 0.012866815093873976
# FILUSD4 and GRTUSD4: pval = 4.6282724762813805e-05
# FILUSD4 and SUSHIUSD4: pval = 0.0001494890890524158
# FILUSD4 and ANKRUSD4: pval = 0.00032425927424608133
# FILUSD4 and CRVUSD4: pval = 0.01394327650790378
# AAVEUSDT and SHIBUSDT: pval = 3.9313096043575034e-08
# AAVEUSDT and CRVUSDT: pval = 8.98932120994083e-06
# AAVEUSD4 and GRTUSD4: pval = 0.0019000815849917903
# AAVEUSD4 and ANKRUSD4: pval = 0.004552840394433078
# AAVEUSD4 and CRVUSD4: pval = 0.029547231215573823
# GRTUSD4 and SUSHIUSD4: pval = 0.010854152119618715
# SUSHIUSD4 and CRVUSD4: pval = 0.01781723995523847
# ANKRUSD4 and CRVUSD4: pval = 0.009566793869571207
# ...
# IOTAUSD and STORJUSD: pval = 0.0023960655997112175
# IOTAUSD and EGLDUSD: pval = 0.0026836092650114147
# IOTAUSD and ZENUSD: pval = 0.027683292911299645
# IOTAUSD and AAVEUSD: pval = 0.016503101355189596
# IOTAUSD and SUSHIUSD: pval = 0.010343484576539436
# IOTAUSD and ANKRUSD: pval = 0.001821518497829483
# IOTAUSD and CRVUSD: pval = 8.367384194775084e-06
# WAVESUSD and ATOMUSD: pval = 0.04484370856807204
# WAVESUSD and NEOUSD: pval = 0.04103687732295791
# WAVESUSD and QTUMUSD: pval = 0.04239932513726791
# WAVESUSD and ZILUSD: pval = 7.89719500336643e-05
# WAVESUSD and EOSUSD: pval = 0.04371427431720486
# WAVESUSD and KNCUSD: pval = 0.0055099294027927525
# WAVESUSD and MANAUSD: pval = 0.0004889934287913614
# WAVESUSD and MKRUSD: pval = 0.012955332361297043
# WAVESUSD and AAVEUSD: pval = 0.03173080310735245
# WAVESUSD and ANKRUSD: pval = 0.030755801987308273
# ATOMUSD and ENJUSD: pval = 0.007324250397907842
# ATOMUSD and XTZUSD: pval = 0.006248976587846295
# ATOMUSD and HBARUSD: pval = 0.026722734487944856
# ATOMUSD and MANAUSD: pval = 1.0982059892920619e-05
# ATOMUSD and MKRUSD: pval = 0.009253477399829419
# ATOMUSD and STORJUSD: pval = 0.019848655896777596
# ATOMUSD and EGLDUSD: pval = 0.01454838374383358
# ATOMUSD and ANKRUSD: pval = 0.023681114535973116
# ATOMUSD and CRVUSD: pval = 0.01176324295698517
# NEOUSD and QTUMUSD: pval = 0.004701563034268465
# NEOUSD and ENJUSD: pval = 2.7223344003115358e-05
# NEOUSD and ONTUSD: pval = 0.03905357586785449
# NEOUSD and DOGEUSD: pval = 0.0014938965002054307
# NEOUSD and MANAUSD: pval = 3.0972301308937426e-06
# NEOUSD and MKRUSD: pval = 0.047223734665000766
# NEOUSD and ONEUSD: pval = 0.01830814081480245
# NEOUSD and STORJUSD: pval = 0.03389596917271676
# NEOUSD and EGLDUSD: pval = 0.00846035299244857
# NEOUSD and OXTUSD: pval = 1.07086544635889e-07
# NEOUSD and ZENUSD: pval = 0.004088532313969319
# NEOUSD and AAVEUSD: pval = 0.010571529703724313
# NEOUSD and GRTUSD: pval = 0.002606782684080118
# NEOUSD and ANKRUSD: pval = 0.004458446993654448
# NEOUSD and CRVUSD: pval = 0.008197348917226111
# QTUMUSD and ICXUSD: pval = 3.88203993682039e-05
# QTUMUSD and ENJUSD: pval = 0.0015000152610334723
# QTUMUSD and ONTUSD: pval = 0.036723736852815464
# QTUMUSD and XTZUSD: pval = 0.0018361600430464194
# QTUMUSD and OMGUSD: pval = 0.00029741025474090595
# QTUMUSD and EOSUSD: pval = 0.000424914560730144
# QTUMUSD and DOGEUSD: pval = 0.020913393643452287
# QTUMUSD and VTHOUSD: pval = 1.74947974287427e-05
# QTUMUSD and COMPUSD: pval = 0.0007170047993258223
# QTUMUSD and MANAUSD: pval = 0.0002405271916860009
# QTUMUSD and BANDUSD: pval = 0.03269277641333668
# QTUMUSD and STORJUSD: pval = 0.020139210452167912
# QTUMUSD and UNIUSD: pval = 0.0229211472145612
# QTUMUSD and EGLDUSD: pval = 0.019469066154842483
# QTUMUSD and ZENUSD: pval = 0.0023715258114703594
# QTUMUSD and FILUSD: pval = 0.00032643504124881104
# QTUMUSD and AAVEUSD: pval = 0.003712129963933055
# QTUMUSD and GRTUSD: pval = 0.0035384593906428816
# QTUMUSD and SUSHIUSD: pval = 0.0001968528644443301
# QTUMUSD and ANKRUSD: pval = 0.02208183346964244
# QTUMUSD and CRVUSD: pval = 0.00910628552031237
# ICXUSD and ENJUSD: pval = 0.00022316200631580595
# ICXUSD and OMGUSD: pval = 0.03200182545375244
# ICXUSD and DOGEUSD: pval = 0.001065398874268632
# ICXUSD and VTHOUSD: pval = 2.023727607237787e-09
# ICXUSD and COMPUSD: pval = 0.00783100779901519
# ICXUSD and MANAUSD: pval = 1.919727017598544e-05
# ICXUSD and ONEUSD: pval = 0.025808562903116544
# ICXUSD and BANDUSD: pval = 2.8219811351210604e-05
# ICXUSD and STORJUSD: pval = 0.016044298482654602
# ICXUSD and EGLDUSD: pval = 0.005075098428435778
# ICXUSD and OXTUSD: pval = 0.002196089985095239
# ICXUSD and ZENUSD: pval = 0.004926712588809571
# ICXUSD and FILUSD: pval = 0.00010548943751007849
# ICXUSD and AAVEUSD: pval = 0.0361485278699369
# ICXUSD and GRTUSD: pval = 5.404855410973447e-06
# ICXUSD and SUSHIUSD: pval = 0.0016928209426395665
# ICXUSD and ANKRUSD: pval = 0.0024177431701897147
# ICXUSD and CRVUSD: pval = 0.0021533712002017712
# ENJUSD and ONTUSD: pval = 0.001223655795721211
# ENJUSD and XTZUSD: pval = 0.003416710752252975
# ENJUSD and HBARUSD: pval = 0.0003108494146852822
# ENJUSD and EOSUSD: pval = 0.0016249435124732988
# ENJUSD and VTHOUSD: pval = 0.009811661678563814
# ENJUSD and COMPUSD: pval = 0.005313450137503082
# ENJUSD and MANAUSD: pval = 0.0005510538693773906
# ENJUSD and MKRUSD: pval = 0.007329452396282267
# ENJUSD and ONEUSD: pval = 0.00016094798746050542
# ENJUSD and BANDUSD: pval = 0.005894099613832668
# ENJUSD and STORJUSD: pval = 0.006495462300233918
# ENJUSD and UNIUSD: pval = 0.01527173975730447
# ENJUSD and EGLDUSD: pval = 0.013902490802100818
# ENJUSD and OXTUSD: pval = 0.00345600155624206
# ENJUSD and ZENUSD: pval = 0.00031618149449245275
# ENJUSD and FILUSD: pval = 0.012321084258632578
# ENJUSD and AAVEUSD: pval = 0.0007934459712331875
# ENJUSD and SUSHIUSD: pval = 0.0035541770139252108
# ENJUSD and ANKRUSD: pval = 0.01515612611696745
# ENJUSD and CRVUSD: pval = 0.000817743277056035
# ONTUSD and XTZUSD: pval = 0.007861991946614426
# ONTUSD and OMGUSD: pval = 0.04365932231873117
# ONTUSD and EOSUSD: pval = 0.008136863561496632
# ONTUSD and MANAUSD: pval = 7.046266626271683e-07
# ONTUSD and MKRUSD: pval = 0.0440579914427904
# ONTUSD and STORJUSD: pval = 0.04242573110529139
# ONTUSD and EGLDUSD: pval = 0.0008524076173858949
# ONTUSD and OXTUSD: pval = 0.005205337241834594
# ONTUSD and ZENUSD: pval = 0.013653668727760932
# ONTUSD and FILUSD: pval = 0.004033795402529799
# ONTUSD and AAVEUSD: pval = 0.0021867387913632984
# ONTUSD and GRTUSD: pval = 0.00043769605288376925
# ONTUSD and SUSHIUSD: pval = 0.03966562343828826
# ONTUSD and ANKRUSD: pval = 0.009570458125049808
# ONTUSD and CRVUSD: pval = 0.004666757704761409
# ZILUSD and XTZUSD: pval = 0.030162316476763092
# ZILUSD and EGLDUSD: pval = 0.02926758798706604
# ZILUSD and ANKRUSD: pval = 0.04284030730511625
# VETUSD and SOLUSD: pval = 0.006566679176723499
# XTZUSD and HBARUSD: pval = 0.0009387022925774594
# XTZUSD and EOSUSD: pval = 0.012461130293584302
# XTZUSD and DOGEUSD: pval = 0.0001949578154507314
# XTZUSD and KNCUSD: pval = 0.030595008104236095
# XTZUSD and COMPUSD: pval = 0.025223516867829022
# XTZUSD and MANAUSD: pval = 5.572266985648216e-07
# XTZUSD and MKRUSD: pval = 0.0007052351835969072
# XTZUSD and ONEUSD: pval = 0.00040717901374528705
# XTZUSD and BANDUSD: pval = 0.020338396211392155
# XTZUSD and STORJUSD: pval = 0.00011905543770275657
# XTZUSD and EGLDUSD: pval = 1.0093220261197124e-05
# XTZUSD and OXTUSD: pval = 0.011122718061740235
# XTZUSD and ZENUSD: pval = 0.00038213912032905096
# XTZUSD and AAVEUSD: pval = 3.850434119305018e-05
# XTZUSD and GRTUSD: pval = 0.00958458087233879
# XTZUSD and SUSHIUSD: pval = 0.018933904392844026
# XTZUSD and ANKRUSD: pval = 6.978960870100379e-05
# XTZUSD and CRVUSD: pval = 1.5264104719632588e-05
# HBARUSD and DOGEUSD: pval = 0.017463105547207383
# HBARUSD and MANAUSD: pval = 1.223754936501618e-06
# HBARUSD and MKRUSD: pval = 0.004345010561700874
# HBARUSD and ONEUSD: pval = 0.0018656447247727798
# HBARUSD and STORJUSD: pval = 0.005405679701306107
# HBARUSD and EGLDUSD: pval = 0.0005970085898467466
# HBARUSD and ZENUSD: pval = 0.04639532445990593
# HBARUSD and AAVEUSD: pval = 0.0104193717097212
# HBARUSD and ANKRUSD: pval = 7.460874158752872e-05
# HBARUSD and CRVUSD: pval = 0.0007584783140253583
# OMGUSD and EOSUSD: pval = 0.03454256402664096
# OMGUSD and DOGEUSD: pval = 0.0062646835938514195
# OMGUSD and VTHOUSD: pval = 0.006291243041729361
# OMGUSD and COMPUSD: pval = 0.013733882798886897
# OMGUSD and MANAUSD: pval = 0.001702184829501993
# OMGUSD and MKRUSD: pval = 0.0195599790806528
# OMGUSD and ONEUSD: pval = 0.01162556967388173
# OMGUSD and BANDUSD: pval = 0.013638315798931511
# OMGUSD and STORJUSD: pval = 0.0007713090907413841
# OMGUSD and EGLDUSD: pval = 0.0006792916646344987
# OMGUSD and OXTUSD: pval = 0.0034196208929332854
# OMGUSD and ZENUSD: pval = 0.0042494399714346496
# OMGUSD and FILUSD: pval = 0.001692644533530065
# OMGUSD and AAVEUSD: pval = 0.02024413508615747
# OMGUSD and GRTUSD: pval = 0.005311162381490906
# OMGUSD and SUSHIUSD: pval = 0.03569273661720247
# OMGUSD and ANKRUSD: pval = 0.000816264501609687
# OMGUSD and CRVUSD: pval = 0.00017840804783491717
# EOSUSD and VTHOUSD: pval = 0.0018238961842590442
# EOSUSD and COMPUSD: pval = 0.0012530624974173392
# EOSUSD and MANAUSD: pval = 1.7860929197736837e-06
# EOSUSD and ONEUSD: pval = 0.0006215063809351347
# EOSUSD and STORJUSD: pval = 0.003755022138613152
# EOSUSD and EGLDUSD: pval = 0.00042075699966268466
# EOSUSD and ZENUSD: pval = 0.001314667953806406
# EOSUSD and AAVEUSD: pval = 3.1946078709550015e-05
# EOSUSD and GRTUSD: pval = 0.0037462676122059333
# EOSUSD and ANKRUSD: pval = 0.001186791645954728
# EOSUSD and CRVUSD: pval = 0.001165266556432377
# DOGEUSD and VTHOUSD: pval = 0.030001833940488387
# DOGEUSD and MANAUSD: pval = 0.007298655868362244
# DOGEUSD and MKRUSD: pval = 0.03419100796963521
# DOGEUSD and BANDUSD: pval = 1.7345017510222196e-07
# DOGEUSD and STORJUSD: pval = 0.015164540339007894
# DOGEUSD and EGLDUSD: pval = 0.0009277065363001093
# DOGEUSD and OXTUSD: pval = 0.0332774121492834
# DOGEUSD and ZENUSD: pval = 0.016273473280197993
# DOGEUSD and FILUSD: pval = 0.03712574170564755
# DOGEUSD and AAVEUSD: pval = 0.005249608450071906
# DOGEUSD and GRTUSD: pval = 0.00694577222086503
# DOGEUSD and SUSHIUSD: pval = 0.02253307387907893
# DOGEUSD and ANKRUSD: pval = 0.02773690619539966
# DOGEUSD and CRVUSD: pval = 0.008831531616495459
# VTHOUSD and COMPUSD: pval = 0.024453756819195167
# VTHOUSD and MANAUSD: pval = 2.7672269363355634e-05
# VTHOUSD and ONEUSD: pval = 0.019099970695656755
# VTHOUSD and STORJUSD: pval = 0.02946332977795232
# VTHOUSD and EGLDUSD: pval = 0.003158156502425749
# VTHOUSD and OXTUSD: pval = 0.00411512293681972
# VTHOUSD and ZENUSD: pval = 0.00016821036152421236
# VTHOUSD and FILUSD: pval = 7.507771007220337e-05
# VTHOUSD and AAVEUSD: pval = 0.012629265752308416
# VTHOUSD and GRTUSD: pval = 4.40908064791017e-06
# VTHOUSD and SUSHIUSD: pval = 0.0007921843342104532
# VTHOUSD and ANKRUSD: pval = 0.004802173818171993
# VTHOUSD and CRVUSD: pval = 0.0008114640804661642
# COMPUSD and MANAUSD: pval = 1.455027033909618e-05
# COMPUSD and ONEUSD: pval = 0.032820683431383925
# COMPUSD and STORJUSD: pval = 0.007115800549757703
# COMPUSD and UNIUSD: pval = 0.01806998444033612
# COMPUSD and EGLDUSD: pval = 0.00034547216843201615
# COMPUSD and OXTUSD: pval = 0.0016422274828829099
# COMPUSD and ZENUSD: pval = 0.0015365979917746507
# COMPUSD and FILUSD: pval = 4.884262615371187e-07
# COMPUSD and AAVEUSD: pval = 0.019711245446441726
# COMPUSD and GRTUSD: pval = 0.0025558966602138087
# COMPUSD and SUSHIUSD: pval = 0.00845315575814494
# COMPUSD and ANKRUSD: pval = 0.010848320098914491
# COMPUSD and CRVUSD: pval = 0.006029809432359252
# MANAUSD and MKRUSD: pval = 0.00016762902593355538
# MANAUSD and ONEUSD: pval = 2.0446106027933023e-06
# MANAUSD and BANDUSD: pval = 0.004443603655891819
# MANAUSD and STORJUSD: pval = 0.00955074426822849
# MANAUSD and UNIUSD: pval = 0.03652552828770725
# MANAUSD and EGLDUSD: pval = 0.0026870547752507155
# MANAUSD and OXTUSD: pval = 0.0003170123153961676
# MANAUSD and ZENUSD: pval = 0.0006081487416128708
# MANAUSD and FILUSD: pval = 0.019010189817316517
# MANAUSD and AAVEUSD: pval = 0.002522881401599154
# MANAUSD and GRTUSD: pval = 0.042782752578660654
# MANAUSD and SUSHIUSD: pval = 0.022355306784401133
# MANAUSD and ANKRUSD: pval = 0.00421525498249356
# MANAUSD and CRVUSD: pval = 2.0703726854349527e-05
# MKRUSD and ONEUSD: pval = 0.031035953849842732
# MKRUSD and STORJUSD: pval = 0.004101132163595773
# MKRUSD and AAVEUSD: pval = 0.012759877838557488
# MKRUSD and ANKRUSD: pval = 0.014481886409364058
# MKRUSD and CRVUSD: pval = 0.008676668008463933
# DAIUSD and ONEUSD: pval = 2.7021709954191054e-11
# DAIUSD and BANDUSD: pval = 3.0556827757982385e-11
# DAIUSD and STORJUSD: pval = 3.000265735782373e-11
# DAIUSD and UNIUSD: pval = 2.984609992218415e-11
# DAIUSD and EGLDUSD: pval = 3.050246602708483e-11
# DAIUSD and PAXGUSD: pval = 9.156883089374038e-11
# DAIUSD and OXTUSD: pval = 3.014279310212021e-11
# DAIUSD and ZENUSD: pval = 2.9023301180516697e-11
# DAIUSD and FILUSD: pval = 2.8610123026389202e-11
# DAIUSD and AAVEUSD: pval = 2.794977238639431e-11
# DAIUSD and GRTUSD: pval = 2.9943627586506735e-11
# DAIUSD and SUSHIUSD: pval = 2.7551393566398584e-11
# DAIUSD and ANKRUSD: pval = 3.2139219244528005e-11
# DAIUSD and CRVUSD: pval = 2.9235207436288943e-11
# ONEUSD and STORJUSD: pval = 0.016952693366018234
# ONEUSD and EGLDUSD: pval = 0.000382460056400055
# ONEUSD and ZENUSD: pval = 0.03651158987995813
# ONEUSD and ANKRUSD: pval = 0.006474882330620204
# ONEUSD and CRVUSD: pval = 0.005151863520238129
# BANDUSD and STORJUSD: pval = 0.045886798706051536
# BANDUSD and EGLDUSD: pval = 0.010694036871846046
# BANDUSD and ZENUSD: pval = 0.0029233233699291383
# BANDUSD and FILUSD: pval = 5.871540026760569e-05
# BANDUSD and AAVEUSD: pval = 0.031406063342632906
# BANDUSD and GRTUSD: pval = 0.0008586233353542472
# BANDUSD and SUSHIUSD: pval = 0.0017381995773118402
# BANDUSD and ANKRUSD: pval = 0.027429312657421503
# BANDUSD and CRVUSD: pval = 0.003102872563092397
# STORJUSD and OXTUSD: pval = 0.029292005055204635
# STORJUSD and FILUSD: pval = 0.02682140042452201
# STORJUSD and AAVEUSD: pval = 0.04448962435289284
# STORJUSD and GRTUSD: pval = 0.01319802988563147
# STORJUSD and CRVUSD: pval = 0.012909421631851435
# UNIUSD and EGLDUSD: pval = 0.020146485389086317
# UNIUSD and OXTUSD: pval = 0.0352249438680238
# UNIUSD and ZENUSD: pval = 0.0055654966474675055
# UNIUSD and FILUSD: pval = 0.034461876813543
# UNIUSD and GRTUSD: pval = 0.016195172717842883
# UNIUSD and SUSHIUSD: pval = 0.001626150681201982
# UNIUSD and ANKRUSD: pval = 0.01714439712998831
# UNIUSD and CRVUSD: pval = 9.723046004190644e-05
# EGLDUSD and OXTUSD: pval = 0.012566673745013324
# EGLDUSD and ZENUSD: pval = 0.0029236307153540334
# EGLDUSD and FILUSD: pval = 0.008160414499499778
# EGLDUSD and AAVEUSD: pval = 0.009135640970086607
# EGLDUSD and GRTUSD: pval = 0.003818318155985063
# EGLDUSD and SUSHIUSD: pval = 0.0005997096843280057
# EGLDUSD and ANKRUSD: pval = 0.0016407424175823753
# EGLDUSD and CRVUSD: pval = 0.0030457841139130636
# OXTUSD and ZENUSD: pval = 0.00022057878143879418
# OXTUSD and AAVEUSD: pval = 0.00135438682599355
# ZENUSD and FILUSD: pval = 0.0006983378220029906
# ZENUSD and AAVEUSD: pval = 0.005364478059695578
# ZENUSD and GRTUSD: pval = 0.0142132032955184
# ZENUSD and SUSHIUSD: pval = 0.0007557559845307065
# ZENUSD and CRVUSD: pval = 0.03468519387795668
# FILUSD and AAVEUSD: pval = 0.002843524658374649
# FILUSD and GRTUSD: pval = 0.003282079872271734
# FILUSD and SUSHIUSD: pval = 9.783501850617245e-06
# FILUSD and ANKRUSD: pval = 2.08306986921904e-05
# FILUSD and CRVUSD: pval = 3.6853581790610955e-05
# AAVEUSD and GRTUSD: pval = 0.0009599471755271849
# AAVEUSD and ANKRUSD: pval = 0.0005285001580553619
# AAVEUSD and CRVUSD: pval = 0.006567697421347674
# GRTUSD and SUSHIUSD: pval = 0.0029924927151312943
# SUSHIUSD and ANKRUSD: pval = 0.0131230870169414
# SUSHIUSD and CRVUSD: pval = 0.003181822287849325
# ANKRUSD and CRVUSD: pval = 0.0013990724656961675
# SNXUSD and AUDIOUSD: pval = 0.0008777974379706049
# SPELLUSD and ROSEUSD: pval = 6.373014521374658e-06
# ANKRUSDT and XTZUSDT: pval = 0.0047710830365436906
# DAIUSDT and DASHUSDT: pval = 4.4897059629635e-12
# DAIUSDT and HBARUSDT: pval = 6.064035282579962e-12
# DAIUSDT and ICXUSDT: pval = 2.0494074722182098e-12
# DAIUSDT and IOTAUSDT: pval = 2.6569685466513262e-12
# DAIUSDT and RVNUSDT: pval = 1.1218696521571656e-12
# DAIUSDT and WAVESUSDT: pval = 2.1620801436134836e-12
# DAIUSDT and XNOUSDT: pval = 2.1868577473882505e-12
# DAIUSDT and XTZUSDT: pval = 1.7334585658104927e-12
# DAIUSDT and ZILUSDT: pval = 1.7842000221605352e-12
# DASHUSDT and RVNUSDT: pval = 0.0055946336612723545
# DASHUSDT and WAVESUSDT: pval = 0.022313438893743875
# DASHUSDT and XNOUSDT: pval = 0.00834351976288762
# DASHUSDT and ZILUSDT: pval = 0.0038907848562738717
# ICXUSDT and WAVESUSDT: pval = 2.1321950914530092e-05
# ICXUSDT and ZILUSDT: pval = 1.301887197288819e-16
# IOTAUSDT and RVNUSDT: pval = 0.013741458082219486
# IOTAUSDT and WAVESUSDT: pval = 0.01949404699549462
# IOTAUSDT and XNOUSDT: pval = 0.02285767705016137
# IOTAUSDT and ZILUSDT: pval = 0.01913989650942094
# RVNUSDT and WAVESUSDT: pval = 1.714929414975099e-05
# WAVESUSDT and XNOUSDT: pval = 0.0003509419812496385
# WAVESUSDT and XTZUSDT: pval = 0.0006874018140925719
# XNOUSDT and ZILUSDT: pval = 0.003399734961749397

# %%
len(cointegrated_pairs)
# Out:
# 1508

# %%
from math import comb

num_pairs = comb(len(tickers), 2)
num_pairs
# Out:
# 143916

# %%
# So 1508 of the 143,916 pairs passed the test...
# This might be too many, I should remove the stable coins first
